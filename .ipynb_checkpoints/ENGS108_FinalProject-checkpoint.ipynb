# %% [markdown]
# # ENGS 108 Applied Machine Learning
# ## Final Project
#
# ### Predicting likelyhood of a song being successful

# %% [markdown]
# Idea from the Kaggle data set found here: https://www.kaggle.com/geomack/spotifyclassification

# %%
import pandas as pd 
import numpy as np
import spotipy 
sp = spotipy.Spotify() 
from spotipy.oauth2 import SpotifyClientCredentials
from sklearn.model_selection import train_test_split
from sklearn import metrics
#for scaling the data
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt

# %%
cid ="af834c73413b4e3abe51409e54a12b56" #CLIENT ID
secret = "c572f66c7257454ea5189dee36084cdd" # CLIENT SECRET

# %%
def get_playlist(user_ID, playlist_URI, cid, secret):
    client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret) 
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) 
    sp.trace=False 
    playlist = sp.user_playlist(user_ID, playlist_URI) 
    songs = playlist["tracks"]["items"] 
    ids = [] 
    titles = []
    artists = []
    for i in range(len(songs)): 
        ids.append(songs[i]["track"]["id"])
        artists.append(songs[i]['track']['artists'][0]['name'])
        titles.append(songs[i]['track']['album']['name'])
    features = sp.audio_features(ids) 
    return pd.DataFrame(features), artists, titles

# %%
user_ID = "gravsibs"
playlist_URI = "7zhfzvSSo9Q0JWzkbw2w5j"
df, df['artist'], df['song_title'] = get_playlist(user_ID, playlist_URI, cid, secret)
df = df.drop(['analysis_url','id','type','track_href','uri'], axis=1)
df['target'] = np.ones(len(df))

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret) 
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) 
sp.trace=False 
playlist = sp.user_playlist(user_ID, playlist_URI) 
songs = playlist["tracks"]["items"] 
ids = [] 
titles = []
artists = []
for i in range(len(songs)): 
    ids.append(songs[i]["track"]["id"])
    artists.append(songs[i]['track']['artists'][0]['name'])
    titles.append(songs[i]['track']['album']['name'])
features = sp.audio_features(ids)

# %% [markdown]
# For each song we get a string of information that looks like this

# %%
playlist
# Out:
# {u'collaborative': False,
#  u'description': None,
#  u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs/playlist/7zhfzvSSo9Q0JWzkbw2w5j'},
#  u'followers': {u'href': None, u'total': 5},
#  u'href': u'https://api.spotify.com/v1/users/gravsibs/playlists/7zhfzvSSo9Q0JWzkbw2w5j',
#  u'id': u'7zhfzvSSo9Q0JWzkbw2w5j',
#  u'images': [{u'height': 640,
#    u'url': u'https://mosaic.scdn.co/640/765a000fecabc76c38e7658ee252aab53c2f3ffd7a8870c5a1381f6b2c63f38ef866d975327eca782bab6c57965383ea93a7eeefe20a1418966ca1dafa760b6efd6f6097217a23894e93925b679dc07b',
#    u'width': 640},
#   {u'height': 300,
#    u'url': u'https://mosaic.scdn.co/300/765a000fecabc76c38e7658ee252aab53c2f3ffd7a8870c5a1381f6b2c63f38ef866d975327eca782bab6c57965383ea93a7eeefe20a1418966ca1dafa760b6efd6f6097217a23894e93925b679dc07b',
#    u'width': 300},
#   {u'height': 60,
#    u'url': u'https://mosaic.scdn.co/60/765a000fecabc76c38e7658ee252aab53c2f3ffd7a8870c5a1381f6b2c63f38ef866d975327eca782bab6c57965383ea93a7eeefe20a1418966ca1dafa760b6efd6f6097217a23894e93925b679dc07b',
#    u'width': 60}],
#  u'name': u'Acquired_Taste',
#  u'owner': {u'display_name': u'J\xf8rgen Grav',
#   u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs'},
#   u'href': u'https://api.spotify.com/v1/users/gravsibs',
#   u'id': u'gravsibs',
#   u'type': u'user',
#   u'uri': u'spotify:user:gravsibs'},
#  u'public': True,
#  u'snapshot_id': u'jLLHeXJxiUPFjGOyJWQp6O24WhknSAReyfeYq/mavUPiUeQZ1OHarGf9N1xOd+v6',
#  u'tracks': {u'href': u'https://api.spotify.com/v1/users/gravsibs/playlists/7zhfzvSSo9Q0JWzkbw2w5j/tracks?offset=0&limit=100',
#   u'items': [{u'added_at': u'2015-07-16T11:26:27Z',
#     u'added_by': {u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs'},
#      u'href': u'https://api.spotify.com/v1/users/gravsibs',
#      u'id': u'gravsibs',
#      u'type': u'user',
#      u'uri': u'spotify:user:gravsibs'},
#     u'is_local': False,
#     u'track': {u'album': {u'album_type': u'single',
#       u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/2QSPrJfYeRXaltEEiriXN9'},
#         u'href': u'https://api.spotify.com/v1/artists/2QSPrJfYeRXaltEEiriXN9',
#         u'id': u'2QSPrJfYeRXaltEEiriXN9',
#         u'name': u'Tove Styrke',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:2QSPrJfYeRXaltEEiriXN9'}],
#       u'available_markets': [u'AD',
#        u'AR',
#        u'AT',
#        u'AU',
#        u'BE',
#        u'BG',
#        u'BO',
#        u'BR',
#        u'CA',
#        u'CH',
#        u'CL',
#        u'CO',
#        u'CR',
#        u'CY',
#        u'CZ',
#        u'DE',
#        u'DK',
#        u'DO',
#        u'EC',
#        u'EE',
#        u'ES',
#        u'FI',
#        u'FR',
#        u'GB',
#        u'GR',
#        u'GT',
#        u'HK',
#        u'HN',
#        u'HU',
#        u'ID',
#        u'IE',
#        u'IS',
#        u'IT',
#        u'JP',
#        u'LI',
#        u'LT',
#        u'LU',
#        u'LV',
#        u'MC',
#        u'MT',
#        u'MX',
#        u'MY',
#        u'NI',
#        u'NL',
#        u'NO',
#        u'NZ',
#        u'PA',
#        u'PE',
#        u'PH',
#        u'PL',
#        u'PT',
#        u'PY',
#        u'SE',
#        u'SG',
#        u'SK',
#        u'SV',
#        u'TH',
#        u'TR',
#        u'TW',
#        u'US',
#        u'UY',
#        u'VN'],
#       u'external_urls': {u'spotify': u'https://open.spotify.com/album/3U7I8KNMVsWaUkyPt2lxBY'},
#       u'href': u'https://api.spotify.com/v1/albums/3U7I8KNMVsWaUkyPt2lxBY',
#       u'id': u'3U7I8KNMVsWaUkyPt2lxBY',
#       u'images': [{u'height': 640,
#         u'url': u'https://i.scdn.co/image/765a000fecabc76c38e7658ee252aab53c2f3ffd',
#         u'width': 640},
#        {u'height': 300,
#         u'url': u'https://i.scdn.co/image/610f52a31025d3906338067f0cdc54d0da1ec4fe',
#         u'width': 300},
#        {u'height': 64,
#         u'url': u'https://i.scdn.co/image/07f7470ae6af3b1135f16e9e1005f09ae512c661',
#         u'width': 64}],
#       u'name': u'Ego (Bearson Remix)',
#       u'type': u'album',
#       u'uri': u'spotify:album:3U7I8KNMVsWaUkyPt2lxBY'},
#      u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/2QSPrJfYeRXaltEEiriXN9'},
#        u'href': u'https://api.spotify.com/v1/artists/2QSPrJfYeRXaltEEiriXN9',
#        u'id': u'2QSPrJfYeRXaltEEiriXN9',
#        u'name': u'Tove Styrke',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:2QSPrJfYeRXaltEEiriXN9'}],
#      u'available_markets': [u'AD',
#       u'AR',
#       u'AT',
#       u'AU',
#       u'BE',
#       u'BG',
#       u'BO',
#       u'BR',
#       u'CA',
#       u'CH',
#       u'CL',
#       u'CO',
#       u'CR',
#       u'CY',
#       u'CZ',
#       u'DE',
#       u'DK',
#       u'DO',
#       u'EC',
#       u'EE',
#       u'ES',
#       u'FI',
#       u'FR',
#       u'GB',
#       u'GR',
#       u'GT',
#       u'HK',
#       u'HN',
#       u'HU',
#       u'ID',
#       u'IE',
#       u'IS',
#       u'IT',
#       u'JP',
#       u'LI',
#       u'LT',
#       u'LU',
#       u'LV',
#       u'MC',
#       u'MT',
#       u'MX',
#       u'MY',
#       u'NI',
#       u'NL',
#       u'NO',
#       u'NZ',
#       u'PA',
#       u'PE',
#       u'PH',
#       u'PL',
#       u'PT',
#       u'PY',
#       u'SE',
#       u'SG',
#       u'SK',
#       u'SV',
#       u'TH',
#       u'TR',
#       u'TW',
#       u'US',
#       u'UY',
#       u'VN'],
#      u'disc_number': 1,
#      u'duration_ms': 239097,
#      u'explicit': False,
#      u'external_ids': {u'isrc': u'SEBGA1500062'},
#      u'external_urls': {u'spotify': u'https://open.spotify.com/track/0W9JOlpUkUfvmwmrayGB4S'},
#      u'href': u'https://api.spotify.com/v1/tracks/0W9JOlpUkUfvmwmrayGB4S',
#      u'id': u'0W9JOlpUkUfvmwmrayGB4S',
#      u'name': u'Ego - Bearson Remix',
#      u'popularity': 33,
#      u'preview_url': u'https://p.scdn.co/mp3-preview/6a55daaac529e80587fc5f2e53b59980a419d79b?cid=af834c73413b4e3abe51409e54a12b56',
#      u'track_number': 1,
#      u'type': u'track',
#      u'uri': u'spotify:track:0W9JOlpUkUfvmwmrayGB4S'}},
#    {u'added_at': u'2015-06-11T12:07:17Z',
#     u'added_by': {u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs'},
#      u'href': u'https://api.spotify.com/v1/users/gravsibs',
#      u'id': u'gravsibs',
#      u'type': u'user',
#      u'uri': u'spotify:user:gravsibs'},
#     u'is_local': False,
#     u'track': {u'album': {u'album_type': u'single',
#       u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/5VXPJC0PNpJbzB10A39G8E'},
#         u'href': u'https://api.spotify.com/v1/artists/5VXPJC0PNpJbzB10A39G8E',
#         u'id': u'5VXPJC0PNpJbzB10A39G8E',
#         u'name': u'Janji',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:5VXPJC0PNpJbzB10A39G8E'}],
#       u'available_markets': [u'AD',
#        u'AR',
#        u'AT',
#        u'AU',
#        u'BE',
#        u'BG',
#        u'BO',
#        u'BR',
#        u'CA',
#        u'CH',
#        u'CL',
#        u'CO',
#        u'CR',
#        u'CY',
#        u'CZ',
#        u'DE',
#        u'DK',
#        u'DO',
#        u'EC',
#        u'EE',
#        u'ES',
#        u'FI',
#        u'FR',
#        u'GB',
#        u'GR',
#        u'GT',
#        u'HK',
#        u'HN',
#        u'HU',
#        u'ID',
#        u'IE',
#        u'IS',
#        u'IT',
#        u'JP',
#        u'LI',
#        u'LT',
#        u'LU',
#        u'LV',
#        u'MC',
#        u'MT',
#        u'MX',
#        u'MY',
#        u'NI',
#        u'NL',
#        u'NO',
#        u'NZ',
#        u'PA',
#        u'PE',
#        u'PH',
#        u'PL',
#        u'PT',
#        u'PY',
#        u'SE',
#        u'SG',
#        u'SK',
#        u'SV',
#        u'TH',
#        u'TR',
#        u'TW',
#        u'US',
#        u'UY',
#        u'VN'],
#       u'external_urls': {u'spotify': u'https://open.spotify.com/album/7zmZ4Kf6fkPBnyZFW4BbqS'},
#       u'href': u'https://api.spotify.com/v1/albums/7zmZ4Kf6fkPBnyZFW4BbqS',
#       u'id': u'7zmZ4Kf6fkPBnyZFW4BbqS',
#       u'images': [{u'height': 640,
#         u'url': u'https://i.scdn.co/image/7a8870c5a1381f6b2c63f38ef866d975327eca78',
#         u'width': 640},
#        {u'height': 300,
#         u'url': u'https://i.scdn.co/image/a8d529e1529e3a18c27bdf4622f78e3b3af332d1',
#         u'width': 300},
#        {u'height': 64,
#         u'url': u'https://i.scdn.co/image/e10f46ad865919041ac5c6551764db4bdfade58e',
#         u'width': 64}],
#       u'name': u'Aurora (feat. T.R.)',
#       u'type': u'album',
#       u'uri': u'spotify:album:7zmZ4Kf6fkPBnyZFW4BbqS'},
#      u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/5VXPJC0PNpJbzB10A39G8E'},
#        u'href': u'https://api.spotify.com/v1/artists/5VXPJC0PNpJbzB10A39G8E',
#        u'id': u'5VXPJC0PNpJbzB10A39G8E',
#        u'name': u'Janji',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:5VXPJC0PNpJbzB10A39G8E'},
#       {u'external_urls': {u'spotify': u'https://open.spotify.com/artist/2LE3RjwF20VLoUjDdl75OU'},
#        u'href': u'https://api.spotify.com/v1/artists/2LE3RjwF20VLoUjDdl75OU',
#        u'id': u'2LE3RjwF20VLoUjDdl75OU',
#        u'name': u'T.R',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:2LE3RjwF20VLoUjDdl75OU'}],
#      u'available_markets': [u'AD',
#       u'AR',
#       u'AT',
#       u'AU',
#       u'BE',
#       u'BG',
#       u'BO',
#       u'BR',
#       u'CA',
#       u'CH',
#       u'CL',
#       u'CO',
#       u'CR',
#       u'CY',
#       u'CZ',
#       u'DE',
#       u'DK',
#       u'DO',
#       u'EC',
#       u'EE',
#       u'ES',
#       u'FI',
#       u'FR',
#       u'GB',
#       u'GR',
#       u'GT',
#       u'HK',
#       u'HN',
#       u'HU',
#       u'ID',
#       u'IE',
#       u'IS',
#       u'IT',
#       u'JP',
#       u'LI',
#       u'LT',
#       u'LU',
#       u'LV',
#       u'MC',
#       u'MT',
#       u'MX',
#       u'MY',
#       u'NI',
#       u'NL',
#       u'NO',
#       u'NZ',
#       u'PA',
#       u'PE',
#       u'PH',
#       u'PL',
#       u'PT',
#       u'PY',
#       u'SE',
#       u'SG',
#       u'SK',
#       u'SV',
#       u'TH',
#       u'TR',
#       u'TW',
#       u'US',
#       u'UY',
#       u'VN'],
#      u'disc_number': 1,
#      u'duration_ms': 262922,
#      u'explicit': False,
#      u'external_ids': {u'isrc': u'GB-SMU-19-41565'},
#      u'external_urls': {u'spotify': u'https://open.spotify.com/track/1R377tvpaz0VIv9yFRCPZP'},
#      u'href': u'https://api.spotify.com/v1/tracks/1R377tvpaz0VIv9yFRCPZP',
#      u'id': u'1R377tvpaz0VIv9yFRCPZP',
#      u'name': u'Aurora (feat. T.R.)',
#      u'popularity': 36,
#      u'preview_url': u'https://p.scdn.co/mp3-preview/33f22bf159d67c320e24a55439c9b2a583e440fc?cid=af834c73413b4e3abe51409e54a12b56',
#      u'track_number': 1,
#      u'type': u'track',
#      u'uri': u'spotify:track:1R377tvpaz0VIv9yFRCPZP'}},
#    {u'added_at': u'2015-06-11T12:09:31Z',
#     u'added_by': {u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs'},
#      u'href': u'https://api.spotify.com/v1/users/gravsibs',
#      u'id': u'gravsibs',
#      u'type': u'user',
#      u'uri': u'spotify:user:gravsibs'},
#     u'is_local': False,
#     u'track': {u'album': {u'album_type': u'single',
#       u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/0pF1TxZmwCJ3gGpkBQwdtT'},
#         u'href': u'https://api.spotify.com/v1/artists/0pF1TxZmwCJ3gGpkBQwdtT',
#         u'id': u'0pF1TxZmwCJ3gGpkBQwdtT',
#         u'name': u'Gabriel Rios',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:0pF1TxZmwCJ3gGpkBQwdtT'}],
#       u'available_markets': [u'AD',
#        u'AR',
#        u'AU',
#        u'BE',
#        u'BG',
#        u'BO',
#        u'BR',
#        u'CA',
#        u'CL',
#        u'CO',
#        u'CR',
#        u'CY',
#        u'CZ',
#        u'DK',
#        u'DO',
#        u'EC',
#        u'EE',
#        u'ES',
#        u'FI',
#        u'FR',
#        u'GB',
#        u'GR',
#        u'GT',
#        u'HK',
#        u'HN',
#        u'HU',
#        u'ID',
#        u'IE',
#        u'IS',
#        u'IT',
#        u'JP',
#        u'LT',
#        u'LU',
#        u'LV',
#        u'MC',
#        u'MT',
#        u'MX',
#        u'MY',
#        u'NI',
#        u'NL',
#        u'NO',
#        u'NZ',
#        u'PA',
#        u'PE',
#        u'PH',
#        u'PL',
#        u'PT',
#        u'PY',
#        u'SE',
#        u'SG',
#        u'SK',
#        u'SV',
#        u'TH',
#        u'TR',
#        u'TW',
#        u'US',
#        u'UY',
#        u'VN'],
#       u'external_urls': {u'spotify': u'https://open.spotify.com/album/3hcn0miMXdXynTRJmAJKYs'},
#       u'href': u'https://api.spotify.com/v1/albums/3hcn0miMXdXynTRJmAJKYs',
#       u'id': u'3hcn0miMXdXynTRJmAJKYs',
#       u'images': [{u'height': 640,
#         u'url': u'https://i.scdn.co/image/2bab6c57965383ea93a7eeefe20a1418966ca1da',
#         u'width': 640},
#        {u'height': 300,
#         u'url': u'https://i.scdn.co/image/891c32a37622f3bce6527494dca89ddbc36234d8',
#         u'width': 300},
#        {u'height': 64,
#         u'url': u'https://i.scdn.co/image/5406e1dbd48658c50b37095c46d6e4cd88c71f5a',
#         u'width': 64}],
#       u'name': u'Gold (Thomas Jack Radio Edit)',
#       u'type': u'album',
#       u'uri': u'spotify:album:3hcn0miMXdXynTRJmAJKYs'},
#      u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/0pF1TxZmwCJ3gGpkBQwdtT'},
#        u'href': u'https://api.spotify.com/v1/artists/0pF1TxZmwCJ3gGpkBQwdtT',
#        u'id': u'0pF1TxZmwCJ3gGpkBQwdtT',
#        u'name': u'Gabriel Rios',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:0pF1TxZmwCJ3gGpkBQwdtT'}],
#      u'available_markets': [u'AD',
#       u'AR',
#       u'AU',
#       u'BE',
#       u'BG',
#       u'BO',
#       u'BR',
#       u'CA',
#       u'CL',
#       u'CO',
#       u'CR',
#       u'CY',
#       u'CZ',
#       u'DK',
#       u'DO',
#       u'EC',
#       u'EE',
#       u'ES',
#       u'FI',
#       u'FR',
#       u'GB',
#       u'GR',
#       u'GT',
#       u'HK',
#       u'HN',
#       u'HU',
#       u'ID',
#       u'IE',
#       u'IS',
#       u'IT',
#       u'JP',
#       u'LT',
#       u'LU',
#       u'LV',
#       u'MC',
#       u'MT',
#       u'MX',
#       u'MY',
#       u'NI',
#       u'NL',
#       u'NO',
#       u'NZ',
#       u'PA',
#       u'PE',
#       u'PH',
#       u'PL',
#       u'PT',
#       u'PY',
#       u'SE',
#       u'SG',
#       u'SK',
#       u'SV',
#       u'TH',
#       u'TR',
#       u'TW',
#       u'US',
#       u'UY',
#       u'VN'],
#      u'disc_number': 1,
#      u'duration_ms': 196310,
#      u'explicit': False,
#      u'external_ids': {u'isrc': u'BEBA51300026'},
#      u'external_urls': {u'spotify': u'https://open.spotify.com/track/6eWsgrQLZhLqy5VfGB9iFs'},
#      u'href': u'https://api.spotify.com/v1/tracks/6eWsgrQLZhLqy5VfGB9iFs',
#      u'id': u'6eWsgrQLZhLqy5VfGB9iFs',
#      u'name': u'Gold - Thomas Jack Radio Edit',
#      u'popularity': 61,
#      u'preview_url': u'https://p.scdn.co/mp3-preview/b34a67a528eb1d2270560b4e3bd200ca4f59edc1?cid=af834c73413b4e3abe51409e54a12b56',
#      u'track_number': 1,
#      u'type': u'track',
#      u'uri': u'spotify:track:6eWsgrQLZhLqy5VfGB9iFs'}},
#    {u'added_at': u'2015-06-11T12:27:52Z',
#     u'added_by': {u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs'},
#      u'href': u'https://api.spotify.com/v1/users/gravsibs',
#      u'id': u'gravsibs',
#      u'type': u'user',
#      u'uri': u'spotify:user:gravsibs'},
#     u'is_local': False,
#     u'track': {u'album': {u'album_type': u'single',
#       u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/22lnnGKlaDxk8sfzCNRJuA'},
#         u'href': u'https://api.spotify.com/v1/artists/22lnnGKlaDxk8sfzCNRJuA',
#         u'id': u'22lnnGKlaDxk8sfzCNRJuA',
#         u'name': u'Diviners',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:22lnnGKlaDxk8sfzCNRJuA'},
#        {u'external_urls': {u'spotify': u'https://open.spotify.com/artist/6rE6zv0dhFUVh35QwO9UyP'},
#         u'href': u'https://api.spotify.com/v1/artists/6rE6zv0dhFUVh35QwO9UyP',
#         u'id': u'6rE6zv0dhFUVh35QwO9UyP',
#         u'name': u'Contacreast',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:6rE6zv0dhFUVh35QwO9UyP'}],
#       u'available_markets': [u'AD',
#        u'AR',
#        u'AT',
#        u'AU',
#        u'BE',
#        u'BG',
#        u'BO',
#        u'BR',
#        u'CA',
#        u'CH',
#        u'CL',
#        u'CO',
#        u'CR',
#        u'CY',
#        u'CZ',
#        u'DE',
#        u'DK',
#        u'DO',
#        u'EC',
#        u'EE',
#        u'ES',
#        u'FI',
#        u'FR',
#        u'GB',
#        u'GR',
#        u'GT',
#        u'HK',
#        u'HN',
#        u'HU',
#        u'ID',
#        u'IE',
#        u'IS',
#        u'IT',
#        u'JP',
#        u'LI',
#        u'LT',
#        u'LU',
#        u'LV',
#        u'MC',
#        u'MT',
#        u'MX',
#        u'MY',
#        u'NI',
#        u'NL',
#        u'NO',
#        u'NZ',
#        u'PA',
#        u'PE',
#        u'PH',
#        u'PL',
#        u'PT',
#        u'PY',
#        u'SE',
#        u'SG',
#        u'SK',
#        u'SV',
#        u'TH',
#        u'TR',
#        u'TW',
#        u'US',
#        u'UY',
#        u'VN'],
#       u'external_urls': {u'spotify': u'https://open.spotify.com/album/2iyxWjV2Rfe04h4uzrkhcX'},
#       u'href': u'https://api.spotify.com/v1/albums/2iyxWjV2Rfe04h4uzrkhcX',
#       u'id': u'2iyxWjV2Rfe04h4uzrkhcX',
#       u'images': [{u'height': 640,
#         u'url': u'https://i.scdn.co/image/fa760b6efd6f6097217a23894e93925b679dc07b',
#         u'width': 640},
#        {u'height': 300,
#         u'url': u'https://i.scdn.co/image/66d39cde269f47723f035abe95b5c58aac187ef9',
#         u'width': 300},
#        {u'height': 64,
#         u'url': u'https://i.scdn.co/image/ff67a4b21da3d8de63253af0c749b5858c8bca07',
#         u'width': 64}],
#       u'name': u'Tropic Love',
#       u'type': u'album',
#       u'uri': u'spotify:album:2iyxWjV2Rfe04h4uzrkhcX'},
#      u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/22lnnGKlaDxk8sfzCNRJuA'},
#        u'href': u'https://api.spotify.com/v1/artists/22lnnGKlaDxk8sfzCNRJuA',
#        u'id': u'22lnnGKlaDxk8sfzCNRJuA',
#        u'name': u'Diviners',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:22lnnGKlaDxk8sfzCNRJuA'},
#       {u'external_urls': {u'spotify': u'https://open.spotify.com/artist/6rE6zv0dhFUVh35QwO9UyP'},
#        u'href': u'https://api.spotify.com/v1/artists/6rE6zv0dhFUVh35QwO9UyP',
#        u'id': u'6rE6zv0dhFUVh35QwO9UyP',
#        u'name': u'Contacreast',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:6rE6zv0dhFUVh35QwO9UyP'}],
#      u'available_markets': [u'AD',
#       u'AR',
#       u'AT',
#       u'AU',
#       u'BE',
#       u'BG',
#       u'BO',
#       u'BR',
#       u'CA',
#       u'CH',
#       u'CL',
#       u'CO',
#       u'CR',
#       u'CY',
#       u'CZ',
#       u'DE',
#       u'DK',
#       u'DO',
#       u'EC',
#       u'EE',
#       u'ES',
#       u'FI',
#       u'FR',
#       u'GB',
#       u'GR',
#       u'GT',
#       u'HK',
#       u'HN',
#       u'HU',
#       u'ID',
#       u'IE',
#       u'IS',
#       u'IT',
#       u'JP',
#       u'LI',
#       u'LT',
#       u'LU',
#       u'LV',
#       u'MC',
#       u'MT',
#       u'MX',
#       u'MY',
#       u'NI',
#       u'NL',
#       u'NO',
#       u'NZ',
#       u'PA',
#       u'PE',
#       u'PH',
#       u'PL',
#       u'PT',
#       u'PY',
#       u'SE',
#       u'SG',
#       u'SK',
#       u'SV',
#       u'TH',
#       u'TR',
#       u'TW',
#       u'US',
#       u'UY',
#       u'VN'],
#      u'disc_number': 1,
#      u'duration_ms': 299440,
#      u'explicit': False,
#      u'external_ids': {u'isrc': u'GB2LD0901946'},
#      u'external_urls': {u'spotify': u'https://open.spotify.com/track/0yxWY5cPaPUpeAoqSIoWfq'},
#      u'href': u'https://api.spotify.com/v1/tracks/0yxWY5cPaPUpeAoqSIoWfq',
#      u'id': u'0yxWY5cPaPUpeAoqSIoWfq',
#      u'name': u'Tropic Love',
#      u'popularity': 54,
#      u'preview_url': u'https://p.scdn.co/mp3-preview/df1e39dbeb526a574792a135bcc663b2a54eefa9?cid=af834c73413b4e3abe51409e54a12b56',
#      u'track_number': 1,
#      u'type': u'track',
#      u'uri': u'spotify:track:0yxWY5cPaPUpeAoqSIoWfq'}},
#    {u'added_at': u'2015-06-15T20:06:11Z',
#     u'added_by': {u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs'},
#      u'href': u'https://api.spotify.com/v1/users/gravsibs',
#      u'id': u'gravsibs',
#      u'type': u'user',
#      u'uri': u'spotify:user:gravsibs'},
#     u'is_local': False,
#     u'track': {u'album': {u'album_type': u'single',
#       u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/5KnoVkIUGmK0PiDKMjz2LM'},
#         u'href': u'https://api.spotify.com/v1/artists/5KnoVkIUGmK0PiDKMjz2LM',
#         u'id': u'5KnoVkIUGmK0PiDKMjz2LM',
#         u'name': u'Feder',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:5KnoVkIUGmK0PiDKMjz2LM'}],
#       u'available_markets': [u'AR',
#        u'AT',
#        u'AU',
#        u'BE',
#        u'BG',
#        u'BO',
#        u'BR',
#        u'CA',
#        u'CH',
#        u'CL',
#        u'CO',
#        u'CR',
#        u'CY',
#        u'CZ',
#        u'DE',
#        u'DK',
#        u'DO',
#        u'EC',
#        u'ES',
#        u'FI',
#        u'GB',
#        u'GR',
#        u'GT',
#        u'HK',
#        u'HN',
#        u'HU',
#        u'ID',
#        u'IE',
#        u'JP',
#        u'LU',
#        u'MT',
#        u'MX',
#        u'MY',
#        u'NI',
#        u'NL',
#        u'NO',
#        u'NZ',
#        u'PA',
#        u'PE',
#        u'PH',
#        u'PT',
#        u'PY',
#        u'SE',
#        u'SG',
#        u'SK',
#        u'SV',
#        u'TH',
#        u'TR',
#        u'TW',
#        u'US',
#        u'UY',
#        u'VN'],
#       u'external_urls': {u'spotify': u'https://open.spotify.com/album/2UGPPuVJHDKLYd9Z2G7zS4'},
#       u'href': u'https://api.spotify.com/v1/albums/2UGPPuVJHDKLYd9Z2G7zS4',
#       u'id': u'2UGPPuVJHDKLYd9Z2G7zS4',
#       u'images': [{u'height': 640,
#         u'url': u'https://i.scdn.co/image/35d32118b40106fa351beca22af65b685505e45d',
#         u'width': 640},
#        {u'height': 300,
#         u'url': u'https://i.scdn.co/image/82bf3ec495ba17d605bb2b73652308265ce9b864',
#         u'width': 300},
#        {u'height': 64,
#         u'url': u'https://i.scdn.co/image/b6f689d434b8c4134fd1d68906faedf0d8fec1f0',
#         u'width': 64}],
#       u'name': u'Goodbye (feat. Lyse) [Radio Edit]',
#       u'type': u'album',
#       u'uri': u'spotify:album:2UGPPuVJHDKLYd9Z2G7zS4'},
#      u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/5KnoVkIUGmK0PiDKMjz2LM'},
#        u'href': u'https://api.spotify.com/v1/artists/5KnoVkIUGmK0PiDKMjz2LM',
#        u'id': u'5KnoVkIUGmK0PiDKMjz2LM',
#        u'name': u'Feder',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:5KnoVkIUGmK0PiDKMjz2LM'},
#       {u'external_urls': {u'spotify': u'https://open.spotify.com/artist/7K9peN1sknRNqPr9YEYedM'},
#        u'href': u'https://api.spotify.com/v1/artists/7K9peN1sknRNqPr9YEYedM',
#        u'id': u'7K9peN1sknRNqPr9YEYedM',
#        u'name': u'Lyse',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:7K9peN1sknRNqPr9YEYedM'}],
#      u'available_markets': [u'AR',
#       u'AT',
#       u'AU',
#       u'BE',
#       u'BG',
#       u'BO',
#       u'BR',
#       u'CA',
#       u'CH',
#       u'CL',
#       u'CO',
#       u'CR',
#       u'CY',
#       u'CZ',
#       u'DE',
#       u'DK',
#       u'DO',
#       u'EC',
#       u'ES',
#       u'FI',
#       u'GB',
#       u'GR',
#       u'GT',
#       u'HK',
#       u'HN',
#       u'HU',
#       u'ID',
#       u'IE',
#       u'JP',
#       u'LU',
#       u'MT',
#       u'MX',
#       u'MY',
#       u'NI',
#       u'NL',
#       u'NO',
#       u'NZ',
#       u'PA',
#       u'PE',
#       u'PH',
#       u'PT',
#       u'PY',
#       u'SE',
#       u'SG',
#       u'SK',
#       u'SV',
#       u'TH',
#       u'TR',
#       u'TW',
#       u'US',
#       u'UY',
#       u'VN'],
#      u'disc_number': 1,
#      u'duration_ms': 201938,
#      u'explicit': False,
#      u'external_ids': {u'isrc': u'ITL011400171'},
#      u'external_urls': {u'spotify': u'https://open.spotify.com/track/3PnOOmkxruDDAiMYZZTgO7'},
#      u'href': u'https://api.spotify.com/v1/tracks/3PnOOmkxruDDAiMYZZTgO7',
#      u'id': u'3PnOOmkxruDDAiMYZZTgO7',
#      u'name': u'Goodbye (feat. Lyse) - Radio Edit',
#      u'popularity': 61,
#      u'preview_url': u'https://p.scdn.co/mp3-preview/676f07c9dca59b9e8b537c528719c1e08e2ea5c9?cid=af834c73413b4e3abe51409e54a12b56',
#      u'track_number': 1,
#      u'type': u'track',
#      u'uri': u'spotify:track:3PnOOmkxruDDAiMYZZTgO7'}},
#    {u'added_at': u'2015-06-16T10:16:26Z',
#     u'added_by': {u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs'},
#      u'href': u'https://api.spotify.com/v1/users/gravsibs',
#      u'id': u'gravsibs',
#      u'type': u'user',
#      u'uri': u'spotify:user:gravsibs'},
#     u'is_local': False,
#     u'track': {u'album': {u'album_type': u'single',
#       u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/2IjiuEObrCKyZvSb8xLxG9'},
#         u'href': u'https://api.spotify.com/v1/artists/2IjiuEObrCKyZvSb8xLxG9',
#         u'id': u'2IjiuEObrCKyZvSb8xLxG9',
#         u'name': u'filous',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:2IjiuEObrCKyZvSb8xLxG9'}],
#       u'available_markets': [u'AD',
#        u'AR',
#        u'AU',
#        u'BE',
#        u'BG',
#        u'BO',
#        u'BR',
#        u'CA',
#        u'CH',
#        u'CL',
#        u'CO',
#        u'CR',
#        u'CY',
#        u'CZ',
#        u'DK',
#        u'DO',
#        u'EC',
#        u'EE',
#        u'ES',
#        u'FI',
#        u'FR',
#        u'GB',
#        u'GR',
#        u'GT',
#        u'HK',
#        u'HN',
#        u'ID',
#        u'IE',
#        u'IS',
#        u'IT',
#        u'LI',
#        u'LT',
#        u'LU',
#        u'LV',
#        u'MC',
#        u'MT',
#        u'MX',
#        u'MY',
#        u'NI',
#        u'NL',
#        u'NO',
#        u'NZ',
#        u'PA',
#        u'PE',
#        u'PH',
#        u'PL',
#        u'PT',
#        u'PY',
#        u'SE',
#        u'SG',
#        u'SK',
#        u'SV',
#        u'TH',
#        u'TR',
#        u'TW',
#        u'US',
#        u'UY',
#        u'VN'],
#       u'external_urls': {u'spotify': u'https://open.spotify.com/album/6cvHoxaW0RCXQMC5xQyAXF'},
#       u'href': u'https://api.spotify.com/v1/albums/6cvHoxaW0RCXQMC5xQyAXF',
#       u'id': u'6cvHoxaW0RCXQMC5xQyAXF',
#       u'images': [{u'height': 640,
#         u'url': u'https://i.scdn.co/image/cc3047e9e75a2384c719cc493f88fae249712a7f',
#         u'width': 640},
#        {u'height': 300,
#         u'url': u'https://i.scdn.co/image/f855e94750c05bf5f103a0e628ce127056de78c6',
#         u'width': 300},
#        {u'height': 64,
#         u'url': u'https://i.scdn.co/image/edf3de406379bb599b974cfd151806b2043228a4',
#         u'width': 64}],
#       u'name': u'How Hard I Try',
#       u'type': u'album',
#       u'uri': u'spotify:album:6cvHoxaW0RCXQMC5xQyAXF'},
#      u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/2IjiuEObrCKyZvSb8xLxG9'},
#        u'href': u'https://api.spotify.com/v1/artists/2IjiuEObrCKyZvSb8xLxG9',
#        u'id': u'2IjiuEObrCKyZvSb8xLxG9',
#        u'name': u'filous',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:2IjiuEObrCKyZvSb8xLxG9'},
#       {u'external_urls': {u'spotify': u'https://open.spotify.com/artist/0lzV2CiahHRiGd6qpADtPS'},
#        u'href': u'https://api.spotify.com/v1/artists/0lzV2CiahHRiGd6qpADtPS',
#        u'id': u'0lzV2CiahHRiGd6qpADtPS',
#        u'name': u'James Hersey',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:0lzV2CiahHRiGd6qpADtPS'}],
#      u'available_markets': [u'AD',
#       u'AR',
#       u'AU',
#       u'BE',
#       u'BG',
#       u'BO',
#       u'BR',
#       u'CA',
#       u'CH',
#       u'CL',
#       u'CO',
#       u'CR',
#       u'CY',
#       u'CZ',
#       u'DK',
#       u'DO',
#       u'EC',
#       u'EE',
#       u'ES',
#       u'FI',
#       u'FR',
#       u'GB',
#       u'GR',
#       u'GT',
#       u'HK',
#       u'HN',
#       u'ID',
#       u'IE',
#       u'IS',
#       u'IT',
#       u'LI',
#       u'LT',
#       u'LU',
#       u'LV',
#       u'MC',
#       u'MT',
#       u'MX',
#       u'MY',
#       u'NI',
#       u'NL',
#       u'NO',
#       u'NZ',
#       u'PA',
#       u'PE',
#       u'PH',
#       u'PL',
#       u'PT',
#       u'PY',
#       u'SE',
#       u'SG',
#       u'SK',
#       u'SV',
#       u'TH',
#       u'TR',
#       u'TW',
#       u'US',
#       u'UY',
#       u'VN'],
#      u'disc_number': 1,
#      u'duration_ms': 198000,
#      u'explicit': False,
#      u'external_ids': {u'isrc': u'USUS11203409'},
#      u'external_urls': {u'spotify': u'https://open.spotify.com/track/7uzudGwu8EG5deuFD7EEJm'},
#      u'href': u'https://api.spotify.com/v1/tracks/7uzudGwu8EG5deuFD7EEJm',
#      u'id': u'7uzudGwu8EG5deuFD7EEJm',
#      u'name': u'How Hard I Try',
#      u'popularity': 56,
#      u'preview_url': u'https://p.scdn.co/mp3-preview/a3a11d277c1ff40af05bc605f5a1b287cdca4879?cid=af834c73413b4e3abe51409e54a12b56',
#      u'track_number': 1,
#      u'type': u'track',
#      u'uri': u'spotify:track:7uzudGwu8EG5deuFD7EEJm'}},
#    {u'added_at': u'2015-06-18T08:12:08Z',
#     u'added_by': {u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs'},
#      u'href': u'https://api.spotify.com/v1/users/gravsibs',
#      u'id': u'gravsibs',
#      u'type': u'user',
#      u'uri': u'spotify:user:gravsibs'},
#     u'is_local': False,
#     u'track': {u'album': {u'album_type': u'single',
#       u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1vIuPjtFhqIPE2n9W2ePgO'},
#         u'href': u'https://api.spotify.com/v1/artists/1vIuPjtFhqIPE2n9W2ePgO',
#         u'id': u'1vIuPjtFhqIPE2n9W2ePgO',
#         u'name': u'Noonie Bao',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:1vIuPjtFhqIPE2n9W2ePgO'}],
#       u'available_markets': [u'DK', u'FI', u'IS', u'NO', u'SE'],
#       u'external_urls': {u'spotify': u'https://open.spotify.com/album/1yGzXAqiWDRrBNbbA4x6H9'},
#       u'href': u'https://api.spotify.com/v1/albums/1yGzXAqiWDRrBNbbA4x6H9',
#       u'id': u'1yGzXAqiWDRrBNbbA4x6H9',
#       u'images': [{u'height': 640,
#         u'url': u'https://i.scdn.co/image/916c0354a0b091ac33fbb88d9540a89c48d66f09',
#         u'width': 640},
#        {u'height': 300,
#         u'url': u'https://i.scdn.co/image/8f53ff8f5c06ef5bba99ed39c51775c0a9812f9e',
#         u'width': 300},
#        {u'height': 64,
#         u'url': u'https://i.scdn.co/image/c07828d18348afe2c2ec99bfe0eb2e03c3b2e1a2',
#         u'width': 64}],
#       u'name': u"I'm In Love (Coucheron Remix)",
#       u'type': u'album',
#       u'uri': u'spotify:album:1yGzXAqiWDRrBNbbA4x6H9'},
#      u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1vIuPjtFhqIPE2n9W2ePgO'},
#        u'href': u'https://api.spotify.com/v1/artists/1vIuPjtFhqIPE2n9W2ePgO',
#        u'id': u'1vIuPjtFhqIPE2n9W2ePgO',
#        u'name': u'Noonie Bao',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:1vIuPjtFhqIPE2n9W2ePgO'},
#       {u'external_urls': {u'spotify': u'https://open.spotify.com/artist/6ly2Z6h9dOerORbK1l2N8D'},
#        u'href': u'https://api.spotify.com/v1/artists/6ly2Z6h9dOerORbK1l2N8D',
#        u'id': u'6ly2Z6h9dOerORbK1l2N8D',
#        u'name': u'Coucheron',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:6ly2Z6h9dOerORbK1l2N8D'}],
#      u'available_markets': [u'DK', u'FI', u'IS', u'NO', u'SE'],
#      u'disc_number': 1,
#      u'duration_ms': 232490,
#      u'explicit': False,
#      u'external_ids': {u'isrc': u'SE3FO1200102'},
#      u'external_urls': {u'spotify': u'https://open.spotify.com/track/1an6lMMwIbYO5LY9kBa7ny'},
#      u'href': u'https://api.spotify.com/v1/tracks/1an6lMMwIbYO5LY9kBa7ny',
#      u'id': u'1an6lMMwIbYO5LY9kBa7ny',
#      u'name': u'I\u2019m In Love - Coucheron Remix',
#      u'popularity': 24,
#      u'preview_url': None,
#      u'track_number': 1,
#      u'type': u'track',
#      u'uri': u'spotify:track:1an6lMMwIbYO5LY9kBa7ny'}},
#    {u'added_at': u'2015-06-30T07:49:20Z',
#     u'added_by': {u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs'},
#      u'href': u'https://api.spotify.com/v1/users/gravsibs',
#      u'id': u'gravsibs',
#      u'type': u'user',
#      u'uri': u'spotify:user:gravsibs'},
#     u'is_local': False,
#     u'track': {u'album': {u'album_type': u'compilation',
#       u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#         u'href': u'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#         u'id': u'0LyfQWJT6nXafLPZqxe9Of',
#         u'name': u'Various Artists',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#       u'available_markets': [],
#       u'external_urls': {u'spotify': u'https://open.spotify.com/album/0L8WBd9LraKHmhmyuaPkj4'},
#       u'href': u'https://api.spotify.com/v1/albums/0L8WBd9LraKHmhmyuaPkj4',
#       u'id': u'0L8WBd9LraKHmhmyuaPkj4',
#       u'images': [{u'height': 640,
#         u'url': u'https://i.scdn.co/image/3c7c9db1df66f72b0d56a7dbf89c23649961b2bd',
#         u'width': 640},
#        {u'height': 300,
#         u'url': u'https://i.scdn.co/image/8d8b478106622fd73d6f65b6e2713e78dfee214c',
#         u'width': 300},
#        {u'height': 64,
#         u'url': u'https://i.scdn.co/image/92806c0496259971e8a0edd25fa75fff981e25ca',
#         u'width': 64}],
#       u'name': u'Next Wave Records',
#       u'type': u'album',
#       u'uri': u'spotify:album:0L8WBd9LraKHmhmyuaPkj4'},
#      u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/356FCJoyYWyzONni54Dgrv'},
#        u'href': u'https://api.spotify.com/v1/artists/356FCJoyYWyzONni54Dgrv',
#        u'id': u'356FCJoyYWyzONni54Dgrv',
#        u'name': u'Jerry Folk',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:356FCJoyYWyzONni54Dgrv'}],
#      u'available_markets': [],
#      u'disc_number': 1,
#      u'duration_ms': 339356,
#      u'explicit': False,
#      u'external_ids': {u'isrc': u'TCACD1529439'},
#      u'external_urls': {u'spotify': u'https://open.spotify.com/track/420XeJ3jD1Q0XHa7v1bgIj'},
#      u'href': u'https://api.spotify.com/v1/tracks/420XeJ3jD1Q0XHa7v1bgIj',
#      u'id': u'420XeJ3jD1Q0XHa7v1bgIj',
#      u'name': u'Talk- Atlas Bound (Jerry Folk Remix)',
#      u'popularity': 0,
#      u'preview_url': None,
#      u'track_number': 4,
#      u'type': u'track',
#      u'uri': u'spotify:track:420XeJ3jD1Q0XHa7v1bgIj'}},
#    {u'added_at': u'2015-07-01T08:34:27Z',
#     u'added_by': {u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs'},
#      u'href': u'https://api.spotify.com/v1/users/gravsibs',
#      u'id': u'gravsibs',
#      u'type': u'user',
#      u'uri': u'spotify:user:gravsibs'},
#     u'is_local': False,
#     u'track': {u'album': {u'album_type': u'album',
#       u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/3fmMaLC5jjf2N4EC2kTx0u'},
#         u'href': u'https://api.spotify.com/v1/artists/3fmMaLC5jjf2N4EC2kTx0u',
#         u'id': u'3fmMaLC5jjf2N4EC2kTx0u',
#         u'name': u'Hermitude',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:3fmMaLC5jjf2N4EC2kTx0u'}],
#       u'available_markets': [u'AU', u'NZ'],
#       u'external_urls': {u'spotify': u'https://open.spotify.com/album/4pGa16elDzoTznDk1Jn1Zj'},
#       u'href': u'https://api.spotify.com/v1/albums/4pGa16elDzoTznDk1Jn1Zj',
#       u'id': u'4pGa16elDzoTznDk1Jn1Zj',
#       u'images': [{u'height': 640,
#         u'url': u'https://i.scdn.co/image/15e3fd5ac47e36c8193473cea0438bb13b0e84b4',
#         u'width': 640},
#        {u'height': 300,
#         u'url': u'https://i.scdn.co/image/bc477e63d3e52b9112d1533a452c2b7315f0b22f',
#         u'width': 300},
#        {u'height': 64,
#         u'url': u'https://i.scdn.co/image/e08a9cd3542676fc44cf064f19c7a7ed3c866f7c',
#         u'width': 64}],
#       u'name': u'Parallel Paradise',
#       u'type': u'album',
#       u'uri': u'spotify:album:4pGa16elDzoTznDk1Jn1Zj'},
#      u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/3fmMaLC5jjf2N4EC2kTx0u'},
#        u'href': u'https://api.spotify.com/v1/artists/3fmMaLC5jjf2N4EC2kTx0u',
#        u'id': u'3fmMaLC5jjf2N4EC2kTx0u',
#        u'name': u'Hermitude',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:3fmMaLC5jjf2N4EC2kTx0u'}],
#      u'available_markets': [u'AU', u'NZ'],
#      u'disc_number': 1,
#      u'duration_ms': 268302,
#      u'explicit': False,
#      u'external_ids': {u'isrc': u'AUEF00900673'},
#      u'external_urls': {u'spotify': u'https://open.spotify.com/track/4WbNyQy4wVdfopMrApBWQA'},
#      u'href': u'https://api.spotify.com/v1/tracks/4WbNyQy4wVdfopMrApBWQA',
#      u'id': u'4WbNyQy4wVdfopMrApBWQA',
#      u'name': u'HyperParadise - Flume Remix',
#      u'popularity': 54,
#      u'preview_url': u'https://p.scdn.co/mp3-preview/d2ba3e1f198f5587675d3c26d17397ffd0b3c3a2?cid=af834c73413b4e3abe51409e54a12b56',
#      u'track_number': 1,
#      u'type': u'track',
#      u'uri': u'spotify:track:4WbNyQy4wVdfopMrApBWQA'}},
#    {u'added_at': u'2015-07-01T08:40:40Z',
#     u'added_by': {u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs'},
#      u'href': u'https://api.spotify.com/v1/users/gravsibs',
#      u'id': u'gravsibs',
#      u'type': u'user',
#      u'uri': u'spotify:user:gravsibs'},
#     u'is_local': False,
#     u'track': {u'album': {u'album_type': u'album',
#       u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1TtJ8j22Roc24e2Jx3OcU4'},
#         u'href': u'https://api.spotify.com/v1/artists/1TtJ8j22Roc24e2Jx3OcU4',
#         u'id': u'1TtJ8j22Roc24e2Jx3OcU4',
#         u'name': u'Purity Ring',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:1TtJ8j22Roc24e2Jx3OcU4'}],
#       u'available_markets': [u'AD',
#        u'AR',
#        u'AT',
#        u'AU',
#        u'BE',
#        u'BG',
#        u'BO',
#        u'BR',
#        u'CH',
#        u'CL',
#        u'CO',
#        u'CR',
#        u'CY',
#        u'CZ',
#        u'DE',
#        u'DK',
#        u'DO',
#        u'EC',
#        u'EE',
#        u'ES',
#        u'FI',
#        u'FR',
#        u'GB',
#        u'GR',
#        u'GT',
#        u'HK',
#        u'HN',
#        u'HU',
#        u'ID',
#        u'IE',
#        u'IS',
#        u'IT',
#        u'JP',
#        u'LI',
#        u'LT',
#        u'LU',
#        u'LV',
#        u'MC',
#        u'MT',
#        u'MX',
#        u'MY',
#        u'NI',
#        u'NL',
#        u'NO',
#        u'NZ',
#        u'PA',
#        u'PE',
#        u'PH',
#        u'PL',
#        u'PT',
#        u'PY',
#        u'SE',
#        u'SG',
#        u'SK',
#        u'SV',
#        u'TH',
#        u'TR',
#        u'TW',
#        u'US',
#        u'UY',
#        u'VN'],
#       u'external_urls': {u'spotify': u'https://open.spotify.com/album/4ymjpcGruNuUUUZOeGawLe'},
#       u'href': u'https://api.spotify.com/v1/albums/4ymjpcGruNuUUUZOeGawLe',
#       u'id': u'4ymjpcGruNuUUUZOeGawLe',
#       u'images': [{u'height': 640,
#         u'url': u'https://i.scdn.co/image/21ea6ee8521cc718464c732fdadb2c8280149797',
#         u'width': 640},
#        {u'height': 300,
#         u'url': u'https://i.scdn.co/image/da37e34124dc3d301528514291e7d153b7ef1cc4',
#         u'width': 300},
#        {u'height': 64,
#         u'url': u'https://i.scdn.co/image/7edff7c7fceb396cf4e4fd9367373833afe45c91',
#         u'width': 64}],
#       u'name': u'another eternity',
#       u'type': u'album',
#       u'uri': u'spotify:album:4ymjpcGruNuUUUZOeGawLe'},
#      u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/1TtJ8j22Roc24e2Jx3OcU4'},
#        u'href': u'https://api.spotify.com/v1/artists/1TtJ8j22Roc24e2Jx3OcU4',
#        u'id': u'1TtJ8j22Roc24e2Jx3OcU4',
#        u'name': u'Purity Ring',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:1TtJ8j22Roc24e2Jx3OcU4'}],
#      u'available_markets': [u'AD',
#       u'AR',
#       u'AT',
#       u'AU',
#       u'BE',
#       u'BG',
#       u'BO',
#       u'BR',
#       u'CH',
#       u'CL',
#       u'CO',
#       u'CR',
#       u'CY',
#       u'CZ',
#       u'DE',
#       u'DK',
#       u'DO',
#       u'EC',
#       u'EE',
#       u'ES',
#       u'FI',
#       u'FR',
#       u'GB',
#       u'GR',
#       u'GT',
#       u'HK',
#       u'HN',
#       u'HU',
#       u'ID',
#       u'IE',
#       u'IS',
#       u'IT',
#       u'JP',
#       u'LI',
#       u'LT',
#       u'LU',
#       u'LV',
#       u'MC',
#       u'MT',
#       u'MX',
#       u'MY',
#       u'NI',
#       u'NL',
#       u'NO',
#       u'NZ',
#       u'PA',
#       u'PE',
#       u'PH',
#       u'PL',
#       u'PT',
#       u'PY',
#       u'SE',
#       u'SG',
#       u'SK',
#       u'SV',
#       u'TH',
#       u'TR',
#       u'TW',
#       u'US',
#       u'UY',
#       u'VN'],
#      u'disc_number': 1,
#      u'duration_ms': 173213,
#      u'explicit': False,
#      u'external_ids': {u'isrc': u'GBAFL1400338'},
#      u'external_urls': {u'spotify': u'https://open.spotify.com/track/2DopRU3QWz4CWymUUrKvO4'},
#      u'href': u'https://api.spotify.com/v1/tracks/2DopRU3QWz4CWymUUrKvO4',
#      u'id': u'2DopRU3QWz4CWymUUrKvO4',
#      u'name': u'bodyache',
#      u'popularity': 59,
#      u'preview_url': u'https://p.scdn.co/mp3-preview/f1c2f15dad1b66ea9360d4b3e6f87b17f3f651e7?cid=af834c73413b4e3abe51409e54a12b56',
#      u'track_number': 2,
#      u'type': u'track',
#      u'uri': u'spotify:track:2DopRU3QWz4CWymUUrKvO4'}},
#    {u'added_at': u'2015-07-01T08:42:05Z',
#     u'added_by': {u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs'},
#      u'href': u'https://api.spotify.com/v1/users/gravsibs',
#      u'id': u'gravsibs',
#      u'type': u'user',
#      u'uri': u'spotify:user:gravsibs'},
#     u'is_local': False,
#     u'track': {u'album': {u'album_type': u'album',
#       u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/4yvcSjfu4PC0CYQyLy4wSq'},
#         u'href': u'https://api.spotify.com/v1/artists/4yvcSjfu4PC0CYQyLy4wSq',
#         u'id': u'4yvcSjfu4PC0CYQyLy4wSq',
#         u'name': u'Glass Animals',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:4yvcSjfu4PC0CYQyLy4wSq'}],
#       u'available_markets': [u'AD',
#        u'AR',
#        u'AT',
#        u'AU',
#        u'BE',
#        u'BG',
#        u'BO',
#        u'BR',
#        u'CH',
#        u'CL',
#        u'CO',
#        u'CR',
#        u'CY',
#        u'CZ',
#        u'DE',
#        u'DK',
#        u'DO',
#        u'EC',
#        u'EE',
#        u'ES',
#        u'FI',
#        u'FR',
#        u'GB',
#        u'GR',
#        u'GT',
#        u'HK',
#        u'HN',
#        u'HU',
#        u'ID',
#        u'IE',
#        u'IS',
#        u'IT',
#        u'LI',
#        u'LT',
#        u'LU',
#        u'LV',
#        u'MC',
#        u'MT',
#        u'MY',
#        u'NI',
#        u'NL',
#        u'NO',
#        u'NZ',
#        u'PA',
#        u'PE',
#        u'PH',
#        u'PL',
#        u'PT',
#        u'PY',
#        u'SE',
#        u'SG',
#        u'SK',
#        u'SV',
#        u'TH',
#        u'TR',
#        u'TW',
#        u'UY',
#        u'VN'],
#       u'external_urls': {u'spotify': u'https://open.spotify.com/album/7jfkffCqKYEJmIgGOIJ9me'},
#       u'href': u'https://api.spotify.com/v1/albums/7jfkffCqKYEJmIgGOIJ9me',
#       u'id': u'7jfkffCqKYEJmIgGOIJ9me',
#       u'images': [{u'height': 640,
#         u'url': u'https://i.scdn.co/image/bff2045f04b67056a31f11c065b3d6019aaab0ca',
#         u'width': 640},
#        {u'height': 300,
#         u'url': u'https://i.scdn.co/image/01634237aed81ac0b8bb56ce1650a22a272691e9',
#         u'width': 300},
#        {u'height': 64,
#         u'url': u'https://i.scdn.co/image/05ec05e978e868501354cb0e8d91aa85c92fde64',
#         u'width': 64}],
#       u'name': u'ZABA',
#       u'type': u'album',
#       u'uri': u'spotify:album:7jfkffCqKYEJmIgGOIJ9me'},
#      u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/4yvcSjfu4PC0CYQyLy4wSq'},
#        u'href': u'https://api.spotify.com/v1/artists/4yvcSjfu4PC0CYQyLy4wSq',
#        u'id': u'4yvcSjfu4PC0CYQyLy4wSq',
#        u'name': u'Glass Animals',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:4yvcSjfu4PC0CYQyLy4wSq'}],
#      u'available_markets': [u'AD',
#       u'AR',
#       u'AT',
#       u'AU',
#       u'BE',
#       u'BG',
#       u'BO',
#       u'BR',
#       u'CH',
#       u'CL',
#       u'CO',
#       u'CR',
#       u'CY',
#       u'CZ',
#       u'DE',
#       u'DK',
#       u'DO',
#       u'EC',
#       u'EE',
#       u'ES',
#       u'FI',
#       u'FR',
#       u'GB',
#       u'GR',
#       u'GT',
#       u'HK',
#       u'HN',
#       u'HU',
#       u'ID',
#       u'IE',
#       u'IS',
#       u'IT',
#       u'LI',
#       u'LT',
#       u'LU',
#       u'LV',
#       u'MC',
#       u'MT',
#       u'MY',
#       u'NI',
#       u'NL',
#       u'NO',
#       u'NZ',
#       u'PA',
#       u'PE',
#       u'PH',
#       u'PL',
#       u'PT',
#       u'PY',
#       u'SE',
#       u'SG',
#       u'SK',
#       u'SV',
#       u'TH',
#       u'TR',
#       u'TW',
#       u'UY',
#       u'VN'],
#      u'disc_number': 1,
#      u'duration_ms': 248920,
#      u'explicit': False,
#      u'external_ids': {u'isrc': u'GBUM71303835'},
#      u'external_urls': {u'spotify': u'https://open.spotify.com/track/1QOltgpJd61c26lVgTCjUj'},
#      u'href': u'https://api.spotify.com/v1/tracks/1QOltgpJd61c26lVgTCjUj',
#      u'id': u'1QOltgpJd61c26lVgTCjUj',
#      u'name': u'Black Mambo',
#      u'popularity': 55,
#      u'preview_url': None,
#      u'track_number': 2,
#      u'type': u'track',
#      u'uri': u'spotify:track:1QOltgpJd61c26lVgTCjUj'}},
#    {u'added_at': u'2015-07-01T09:01:45Z',
#     u'added_by': {u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs'},
#      u'href': u'https://api.spotify.com/v1/users/gravsibs',
#      u'id': u'gravsibs',
#      u'type': u'user',
#      u'uri': u'spotify:user:gravsibs'},
#     u'is_local': False,
#     u'track': {u'album': {u'album_type': u'album',
#       u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/21mKp7DqtSNHhCAU2ugvUw'},
#         u'href': u'https://api.spotify.com/v1/artists/21mKp7DqtSNHhCAU2ugvUw',
#         u'id': u'21mKp7DqtSNHhCAU2ugvUw',
#         u'name': u'ODESZA',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:21mKp7DqtSNHhCAU2ugvUw'}],
#       u'available_markets': [u'AD',
#        u'AR',
#        u'AT',
#        u'BE',
#        u'BG',
#        u'BO',
#        u'BR',
#        u'CA',
#        u'CH',
#        u'CL',
#        u'CO',
#        u'CR',
#        u'CY',
#        u'CZ',
#        u'DE',
#        u'DK',
#        u'DO',
#        u'EC',
#        u'EE',
#        u'ES',
#        u'FI',
#        u'FR',
#        u'GB',
#        u'GR',
#        u'GT',
#        u'HK',
#        u'HN',
#        u'HU',
#        u'ID',
#        u'IE',
#        u'IS',
#        u'IT',
#        u'LI',
#        u'LT',
#        u'LU',
#        u'LV',
#        u'MC',
#        u'MT',
#        u'MX',
#        u'MY',
#        u'NI',
#        u'NL',
#        u'NO',
#        u'PA',
#        u'PE',
#        u'PH',
#        u'PL',
#        u'PT',
#        u'PY',
#        u'SE',
#        u'SG',
#        u'SK',
#        u'SV',
#        u'TH',
#        u'TR',
#        u'TW',
#        u'US',
#        u'UY',
#        u'VN'],
#       u'external_urls': {u'spotify': u'https://open.spotify.com/album/5SXT6dwhHX56Sos7KMcMF5'},
#       u'href': u'https://api.spotify.com/v1/albums/5SXT6dwhHX56Sos7KMcMF5',
#       u'id': u'5SXT6dwhHX56Sos7KMcMF5',
#       u'images': [{u'height': 640,
#         u'url': u'https://i.scdn.co/image/387b19d3bc6178b7429493f9fdf4f7c8c33aabc5',
#         u'width': 640},
#        {u'height': 300,
#         u'url': u'https://i.scdn.co/image/4665e5c03ce459972642c794bcd71a5bc65c24c1',
#         u'width': 300},
#        {u'height': 64,
#         u'url': u'https://i.scdn.co/image/3e0f724ed60e3b66716dba75245bfe231626f1a7',
#         u'width': 64}],
#       u'name': u'In Return',
#       u'type': u'album',
#       u'uri': u'spotify:album:5SXT6dwhHX56Sos7KMcMF5'},
#      u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/21mKp7DqtSNHhCAU2ugvUw'},
#        u'href': u'https://api.spotify.com/v1/artists/21mKp7DqtSNHhCAU2ugvUw',
#        u'id': u'21mKp7DqtSNHhCAU2ugvUw',
#        u'name': u'ODESZA',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:21mKp7DqtSNHhCAU2ugvUw'},
#       {u'external_urls': {u'spotify': u'https://open.spotify.com/artist/4oFdxup3UmMDNoLLITyDrs'},
#        u'href': u'https://api.spotify.com/v1/artists/4oFdxup3UmMDNoLLITyDrs',
#        u'id': u'4oFdxup3UmMDNoLLITyDrs',
#        u'name': u'Shy Girls',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:4oFdxup3UmMDNoLLITyDrs'}],
#      u'available_markets': [u'AD',
#       u'AR',
#       u'AT',
#       u'BE',
#       u'BG',
#       u'BO',
#       u'BR',
#       u'CA',
#       u'CH',
#       u'CL',
#       u'CO',
#       u'CR',
#       u'CY',
#       u'CZ',
#       u'DE',
#       u'DK',
#       u'DO',
#       u'EC',
#       u'EE',
#       u'ES',
#       u'FI',
#       u'FR',
#       u'GB',
#       u'GR',
#       u'GT',
#       u'HK',
#       u'HN',
#       u'HU',
#       u'ID',
#       u'IE',
#       u'IS',
#       u'IT',
#       u'LI',
#       u'LT',
#       u'LU',
#       u'LV',
#       u'MC',
#       u'MT',
#       u'MX',
#       u'MY',
#       u'NI',
#       u'NL',
#       u'NO',
#       u'PA',
#       u'PE',
#       u'PH',
#       u'PL',
#       u'PT',
#       u'PY',
#       u'SE',
#       u'SG',
#       u'SK',
#       u'SV',
#       u'TH',
#       u'TR',
#       u'TW',
#       u'US',
#       u'UY',
#       u'VN'],
#      u'disc_number': 1,
#      u'duration_ms': 211200,
#      u'explicit': False,
#      u'external_ids': {u'isrc': u'GBCFB1404203'},
#      u'external_urls': {u'spotify': u'https://open.spotify.com/track/5jnp8E61wcoF6qIEtDHQnJ'},
#      u'href': u'https://api.spotify.com/v1/tracks/5jnp8E61wcoF6qIEtDHQnJ',
#      u'id': u'5jnp8E61wcoF6qIEtDHQnJ',
#      u'name': u'All We Need (feat. Shy Girls)',
#      u'popularity': 60,
#      u'preview_url': u'https://p.scdn.co/mp3-preview/182a0da79749a5e6a44378700670c671780fcb44?cid=af834c73413b4e3abe51409e54a12b56',
#      u'track_number': 4,
#      u'type': u'track',
#      u'uri': u'spotify:track:5jnp8E61wcoF6qIEtDHQnJ'}},
#    {u'added_at': u'2015-07-01T10:50:18Z',
# ...
#         u'width': 640},
#        {u'height': 300,
#         u'url': u'https://i.scdn.co/image/b3ba4d48745a7220256531106892ab8631f27f45',
#         u'width': 300},
#        {u'height': 64,
#         u'url': u'https://i.scdn.co/image/8a511b8522df11e25b351b2aa28f6d2a2b0fdace',
#         u'width': 64}],
#       u'name': u'Chemicals (Remixes)',
#       u'type': u'album',
#       u'uri': u'spotify:album:0R4QzPTrlSmTRITSfjTbyN'},
#      u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/3ua4MYAHmkOM1hL7o0FqIw'},
#        u'href': u'https://api.spotify.com/v1/artists/3ua4MYAHmkOM1hL7o0FqIw',
#        u'id': u'3ua4MYAHmkOM1hL7o0FqIw',
#        u'name': u'Sirena',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:3ua4MYAHmkOM1hL7o0FqIw'},
#       {u'external_urls': {u'spotify': u'https://open.spotify.com/artist/2HakJdGe3hFDmSS1mTwIaR'},
#        u'href': u'https://api.spotify.com/v1/artists/2HakJdGe3hFDmSS1mTwIaR',
#        u'id': u'2HakJdGe3hFDmSS1mTwIaR',
#        u'name': u'Alessandro Addea',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:2HakJdGe3hFDmSS1mTwIaR'}],
#      u'available_markets': [u'AD',
#       u'AR',
#       u'AT',
#       u'AU',
#       u'BE',
#       u'BG',
#       u'BO',
#       u'BR',
#       u'CH',
#       u'CL',
#       u'CO',
#       u'CR',
#       u'CY',
#       u'CZ',
#       u'DE',
#       u'DK',
#       u'DO',
#       u'EC',
#       u'EE',
#       u'ES',
#       u'FI',
#       u'FR',
#       u'GB',
#       u'GR',
#       u'GT',
#       u'HK',
#       u'HN',
#       u'HU',
#       u'ID',
#       u'IE',
#       u'IS',
#       u'IT',
#       u'JP',
#       u'LI',
#       u'LT',
#       u'LU',
#       u'LV',
#       u'MC',
#       u'MT',
#       u'MY',
#       u'NI',
#       u'NL',
#       u'NO',
#       u'NZ',
#       u'PA',
#       u'PE',
#       u'PH',
#       u'PL',
#       u'PT',
#       u'PY',
#       u'SE',
#       u'SG',
#       u'SK',
#       u'SV',
#       u'TH',
#       u'TR',
#       u'TW',
#       u'UY',
#       u'VN'],
#      u'disc_number': 1,
#      u'duration_ms': 208818,
#      u'explicit': False,
#      u'external_ids': {u'isrc': u'SE32S1400202'},
#      u'external_urls': {u'spotify': u'https://open.spotify.com/track/5VXiwXB95tfgcmqPX2xGQ9'},
#      u'href': u'https://api.spotify.com/v1/tracks/5VXiwXB95tfgcmqPX2xGQ9',
#      u'id': u'5VXiwXB95tfgcmqPX2xGQ9',
#      u'name': u'Chemicals - Addal Remix',
#      u'popularity': 29,
#      u'preview_url': None,
#      u'track_number': 2,
#      u'type': u'track',
#      u'uri': u'spotify:track:5VXiwXB95tfgcmqPX2xGQ9'}},
#    {u'added_at': u'2016-04-05T15:17:32Z',
#     u'added_by': {u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs'},
#      u'href': u'https://api.spotify.com/v1/users/gravsibs',
#      u'id': u'gravsibs',
#      u'type': u'user',
#      u'uri': u'spotify:user:gravsibs'},
#     u'is_local': False,
#     u'track': {u'album': {u'album_type': u'single',
#       u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/65rMJvtegr9sVtUgyAdPBS'},
#         u'href': u'https://api.spotify.com/v1/artists/65rMJvtegr9sVtUgyAdPBS',
#         u'id': u'65rMJvtegr9sVtUgyAdPBS',
#         u'name': u'Holland Park',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:65rMJvtegr9sVtUgyAdPBS'}],
#       u'available_markets': [u'AD',
#        u'AR',
#        u'AT',
#        u'BG',
#        u'BO',
#        u'BR',
#        u'CA',
#        u'CH',
#        u'CL',
#        u'CY',
#        u'CZ',
#        u'DE',
#        u'DK',
#        u'DO',
#        u'EC',
#        u'EE',
#        u'ES',
#        u'FI',
#        u'FR',
#        u'GB',
#        u'GR',
#        u'GT',
#        u'HK',
#        u'HU',
#        u'ID',
#        u'IE',
#        u'IS',
#        u'IT',
#        u'LI',
#        u'LT',
#        u'LV',
#        u'MC',
#        u'MT',
#        u'MY',
#        u'NL',
#        u'NO',
#        u'PE',
#        u'PH',
#        u'PL',
#        u'PT',
#        u'PY',
#        u'SE',
#        u'SG',
#        u'SK',
#        u'TH',
#        u'TR',
#        u'TW',
#        u'US',
#        u'UY',
#        u'VN'],
#       u'external_urls': {u'spotify': u'https://open.spotify.com/album/6GUyTd8uT8NaS77zVP4dih'},
#       u'href': u'https://api.spotify.com/v1/albums/6GUyTd8uT8NaS77zVP4dih',
#       u'id': u'6GUyTd8uT8NaS77zVP4dih',
#       u'images': [{u'height': 640,
#         u'url': u'https://i.scdn.co/image/3d35b26bd476316b7e32030bb6f1ee321513ac43',
#         u'width': 640},
#        {u'height': 300,
#         u'url': u'https://i.scdn.co/image/8385ca702303ce541e970b7dc6847fb0b642281a',
#         u'width': 300},
#        {u'height': 64,
#         u'url': u'https://i.scdn.co/image/516c9df4268892c0b7b4443a1f2ac80e85f164f0',
#         u'width': 64}],
#       u'name': u'Crime ft. Liam Allan',
#       u'type': u'album',
#       u'uri': u'spotify:album:6GUyTd8uT8NaS77zVP4dih'},
#      u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/65rMJvtegr9sVtUgyAdPBS'},
#        u'href': u'https://api.spotify.com/v1/artists/65rMJvtegr9sVtUgyAdPBS',
#        u'id': u'65rMJvtegr9sVtUgyAdPBS',
#        u'name': u'Holland Park',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:65rMJvtegr9sVtUgyAdPBS'},
#       {u'external_urls': {u'spotify': u'https://open.spotify.com/artist/4gx1rMRTWR3DFKJwolZxCg'},
#        u'href': u'https://api.spotify.com/v1/artists/4gx1rMRTWR3DFKJwolZxCg',
#        u'id': u'4gx1rMRTWR3DFKJwolZxCg',
#        u'name': u'Liam Allan',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:4gx1rMRTWR3DFKJwolZxCg'}],
#      u'available_markets': [u'AD',
#       u'AR',
#       u'AT',
#       u'BG',
#       u'BO',
#       u'BR',
#       u'CA',
#       u'CH',
#       u'CL',
#       u'CY',
#       u'CZ',
#       u'DE',
#       u'DK',
#       u'DO',
#       u'EC',
#       u'EE',
#       u'ES',
#       u'FI',
#       u'FR',
#       u'GB',
#       u'GR',
#       u'GT',
#       u'HK',
#       u'HU',
#       u'ID',
#       u'IE',
#       u'IS',
#       u'IT',
#       u'LI',
#       u'LT',
#       u'LV',
#       u'MC',
#       u'MT',
#       u'MY',
#       u'NL',
#       u'NO',
#       u'PE',
#       u'PH',
#       u'PL',
#       u'PT',
#       u'PY',
#       u'SE',
#       u'SG',
#       u'SK',
#       u'TH',
#       u'TR',
#       u'TW',
#       u'US',
#       u'UY',
#       u'VN'],
#      u'disc_number': 1,
#      u'duration_ms': 320640,
#      u'explicit': False,
#      u'external_ids': {u'isrc': u'NLZ541500005'},
#      u'external_urls': {u'spotify': u'https://open.spotify.com/track/4jlx64qszJP4z62GyZi154'},
#      u'href': u'https://api.spotify.com/v1/tracks/4jlx64qszJP4z62GyZi154',
#      u'id': u'4jlx64qszJP4z62GyZi154',
#      u'name': u'Crime ft. Liam Allan - Extended Mix',
#      u'popularity': 26,
#      u'preview_url': u'https://p.scdn.co/mp3-preview/31dc9e602a5af7ca1f8b1842cdc9411d0f9e4848?cid=af834c73413b4e3abe51409e54a12b56',
#      u'track_number': 2,
#      u'type': u'track',
#      u'uri': u'spotify:track:4jlx64qszJP4z62GyZi154'}},
#    {u'added_at': u'2016-04-05T15:17:32Z',
#     u'added_by': {u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs'},
#      u'href': u'https://api.spotify.com/v1/users/gravsibs',
#      u'id': u'gravsibs',
#      u'type': u'user',
#      u'uri': u'spotify:user:gravsibs'},
#     u'is_local': False,
#     u'track': {u'album': {u'album_type': u'single',
#       u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/2KsP6tYLJlTBvSUxnwlVWa'},
#         u'href': u'https://api.spotify.com/v1/artists/2KsP6tYLJlTBvSUxnwlVWa',
#         u'id': u'2KsP6tYLJlTBvSUxnwlVWa',
#         u'name': u'Mike Posner',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:2KsP6tYLJlTBvSUxnwlVWa'}],
#       u'available_markets': [u'AD',
#        u'AR',
#        u'AT',
#        u'AU',
#        u'BE',
#        u'BG',
#        u'BO',
#        u'BR',
#        u'CH',
#        u'CL',
#        u'CO',
#        u'CR',
#        u'CY',
#        u'CZ',
#        u'DE',
#        u'DK',
#        u'DO',
#        u'EC',
#        u'EE',
#        u'ES',
#        u'FI',
#        u'GB',
#        u'GR',
#        u'GT',
#        u'HK',
#        u'HN',
#        u'HU',
#        u'ID',
#        u'IE',
#        u'IS',
#        u'IT',
#        u'LI',
#        u'LT',
#        u'LU',
#        u'LV',
#        u'MC',
#        u'MT',
#        u'MY',
#        u'NI',
#        u'NL',
#        u'NO',
#        u'NZ',
#        u'PA',
#        u'PE',
#        u'PH',
#        u'PL',
#        u'PT',
#        u'PY',
#        u'SG',
#        u'SK',
#        u'SV',
#        u'TH',
#        u'TR',
#        u'TW',
#        u'UY',
#        u'VN'],
#       u'external_urls': {u'spotify': u'https://open.spotify.com/album/31VgmdtmYLMb31XhP3RPVc'},
#       u'href': u'https://api.spotify.com/v1/albums/31VgmdtmYLMb31XhP3RPVc',
#       u'id': u'31VgmdtmYLMb31XhP3RPVc',
#       u'images': [{u'height': 640,
#         u'url': u'https://i.scdn.co/image/c468bb40de5e2be22de0602e3248d223af669c65',
#         u'width': 640},
#        {u'height': 300,
#         u'url': u'https://i.scdn.co/image/7832ebbdcd78f4c27cf7b27ce1cbfc754499b8fa',
#         u'width': 300},
#        {u'height': 64,
#         u'url': u'https://i.scdn.co/image/9146c95a9f99c240137bc45a2241c858e11247ae',
#         u'width': 64}],
#       u'name': u'I Took A Pill In Ibiza (Seeb Remix)',
#       u'type': u'album',
#       u'uri': u'spotify:album:31VgmdtmYLMb31XhP3RPVc'},
#      u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/2KsP6tYLJlTBvSUxnwlVWa'},
#        u'href': u'https://api.spotify.com/v1/artists/2KsP6tYLJlTBvSUxnwlVWa',
#        u'id': u'2KsP6tYLJlTBvSUxnwlVWa',
#        u'name': u'Mike Posner',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:2KsP6tYLJlTBvSUxnwlVWa'},
#       {u'external_urls': {u'spotify': u'https://open.spotify.com/artist/5iNrZmtVMtYev5M9yoWpEq'},
#        u'href': u'https://api.spotify.com/v1/artists/5iNrZmtVMtYev5M9yoWpEq',
#        u'id': u'5iNrZmtVMtYev5M9yoWpEq',
#        u'name': u'Seeb',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:5iNrZmtVMtYev5M9yoWpEq'}],
#      u'available_markets': [u'AD',
#       u'AR',
#       u'AT',
#       u'AU',
#       u'BE',
#       u'BG',
#       u'BO',
#       u'BR',
#       u'CH',
#       u'CL',
#       u'CO',
#       u'CR',
#       u'CY',
#       u'CZ',
#       u'DE',
#       u'DK',
#       u'DO',
#       u'EC',
#       u'EE',
#       u'ES',
#       u'FI',
#       u'GB',
#       u'GR',
#       u'GT',
#       u'HK',
#       u'HN',
#       u'HU',
#       u'ID',
#       u'IE',
#       u'IS',
#       u'IT',
#       u'LI',
#       u'LT',
#       u'LU',
#       u'LV',
#       u'MC',
#       u'MT',
#       u'MY',
#       u'NI',
#       u'NL',
#       u'NO',
#       u'NZ',
#       u'PA',
#       u'PE',
#       u'PH',
#       u'PL',
#       u'PT',
#       u'PY',
#       u'SG',
#       u'SK',
#       u'SV',
#       u'TH',
#       u'TR',
#       u'TW',
#       u'UY',
#       u'VN'],
#      u'disc_number': 1,
#      u'duration_ms': 199226,
#      u'explicit': True,
#      u'external_ids': {u'isrc': u'USUM71509342'},
#      u'external_urls': {u'spotify': u'https://open.spotify.com/track/7vfWgVGiLgnGbInU5lvSQg'},
#      u'href': u'https://api.spotify.com/v1/tracks/7vfWgVGiLgnGbInU5lvSQg',
#      u'id': u'7vfWgVGiLgnGbInU5lvSQg',
#      u'name': u'I Took A Pill In Ibiza - Seeb Remix',
#      u'popularity': 72,
#      u'preview_url': None,
#      u'track_number': 1,
#      u'type': u'track',
#      u'uri': u'spotify:track:7vfWgVGiLgnGbInU5lvSQg'}},
#    {u'added_at': u'2016-04-05T15:17:32Z',
#     u'added_by': {u'external_urls': {u'spotify': u'http://open.spotify.com/user/gravsibs'},
#      u'href': u'https://api.spotify.com/v1/users/gravsibs',
#      u'id': u'gravsibs',
#      u'type': u'user',
#      u'uri': u'spotify:user:gravsibs'},
#     u'is_local': False,
#     u'track': {u'album': {u'album_type': u'single',
#       u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/4ipsWRARKiEtADamANhIxc'},
#         u'href': u'https://api.spotify.com/v1/artists/4ipsWRARKiEtADamANhIxc',
#         u'id': u'4ipsWRARKiEtADamANhIxc',
#         u'name': u'Alex and The Talai Lama',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:4ipsWRARKiEtADamANhIxc'},
#        {u'external_urls': {u'spotify': u'https://open.spotify.com/artist/3klPstTeeTJ1vXH3VxVrgD'},
#         u'href': u'https://api.spotify.com/v1/artists/3klPstTeeTJ1vXH3VxVrgD',
#         u'id': u'3klPstTeeTJ1vXH3VxVrgD',
#         u'name': u'Bjorn',
#         u'type': u'artist',
#         u'uri': u'spotify:artist:3klPstTeeTJ1vXH3VxVrgD'}],
#       u'available_markets': [u'AD',
#        u'AR',
#        u'AT',
#        u'AU',
#        u'BE',
#        u'BG',
#        u'BO',
#        u'BR',
#        u'CA',
#        u'CH',
#        u'CL',
#        u'CO',
#        u'CR',
#        u'CY',
#        u'CZ',
#        u'DE',
#        u'DK',
#        u'DO',
#        u'EC',
#        u'EE',
#        u'ES',
#        u'FI',
#        u'FR',
#        u'GB',
#        u'GR',
#        u'GT',
#        u'HK',
#        u'HN',
#        u'HU',
#        u'ID',
#        u'IE',
#        u'IS',
#        u'IT',
#        u'JP',
#        u'LI',
#        u'LT',
#        u'LU',
#        u'LV',
#        u'MC',
#        u'MT',
#        u'MX',
#        u'MY',
#        u'NI',
#        u'NL',
#        u'NO',
#        u'NZ',
#        u'PA',
#        u'PE',
#        u'PH',
#        u'PL',
#        u'PT',
#        u'PY',
#        u'SE',
#        u'SG',
#        u'SK',
#        u'SV',
#        u'TH',
#        u'TR',
#        u'TW',
#        u'US',
#        u'UY',
#        u'VN'],
#       u'external_urls': {u'spotify': u'https://open.spotify.com/album/6aYjuzCcmvFitsQJnZ27Lw'},
#       u'href': u'https://api.spotify.com/v1/albums/6aYjuzCcmvFitsQJnZ27Lw',
#       u'id': u'6aYjuzCcmvFitsQJnZ27Lw',
#       u'images': [{u'height': 640,
#         u'url': u'https://i.scdn.co/image/24beec9cc44c8694e17e2d622622e612d2af3f8a',
#         u'width': 640},
#        {u'height': 300,
#         u'url': u'https://i.scdn.co/image/649557fdb2316fbd53448bb97603e81ac0e88dff',
#         u'width': 300},
#        {u'height': 64,
#         u'url': u'https://i.scdn.co/image/661113042abb691986679d2bd8ee3ac68530f19b',
#         u'width': 64}],
#       u'name': u'Ghost (Bj\xf6rn Remix)',
#       u'type': u'album',
#       u'uri': u'spotify:album:6aYjuzCcmvFitsQJnZ27Lw'},
#      u'artists': [{u'external_urls': {u'spotify': u'https://open.spotify.com/artist/4ipsWRARKiEtADamANhIxc'},
#        u'href': u'https://api.spotify.com/v1/artists/4ipsWRARKiEtADamANhIxc',
#        u'id': u'4ipsWRARKiEtADamANhIxc',
#        u'name': u'Alex and The Talai Lama',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:4ipsWRARKiEtADamANhIxc'},
#       {u'external_urls': {u'spotify': u'https://open.spotify.com/artist/3klPstTeeTJ1vXH3VxVrgD'},
#        u'href': u'https://api.spotify.com/v1/artists/3klPstTeeTJ1vXH3VxVrgD',
#        u'id': u'3klPstTeeTJ1vXH3VxVrgD',
#        u'name': u'Bjorn',
#        u'type': u'artist',
#        u'uri': u'spotify:artist:3klPstTeeTJ1vXH3VxVrgD'}],
#      u'available_markets': [u'AD',
#       u'AR',
#       u'AT',
#       u'AU',
#       u'BE',
#       u'BG',
#       u'BO',
#       u'BR',
#       u'CA',
#       u'CH',
#       u'CL',
#       u'CO',
#       u'CR',
#       u'CY',
#       u'CZ',
#       u'DE',
#       u'DK',
#       u'DO',
#       u'EC',
#       u'EE',
#       u'ES',
#       u'FI',
#       u'FR',
#       u'GB',
#       u'GR',
#       u'GT',
#       u'HK',
#       u'HN',
#       u'HU',
#       u'ID',
#       u'IE',
#       u'IS',
#       u'IT',
#       u'JP',
#       u'LI',
#       u'LT',
#       u'LU',
#       u'LV',
#       u'MC',
#       u'MT',
#       u'MX',
#       u'MY',
#       u'NI',
#       u'NL',
#       u'NO',
#       u'NZ',
#       u'PA',
#       u'PE',
#       u'PH',
#       u'PL',
#       u'PT',
#       u'PY',
#       u'SE',
#       u'SG',
#       u'SK',
#       u'SV',
#       u'TH',
#       u'TR',
#       u'TW',
#       u'US',
#       u'UY',
#       u'VN'],
#      u'disc_number': 1,
#      u'duration_ms': 279510,
#      u'explicit': False,
#      u'external_ids': {u'isrc': u'GB-SMU-22-25867'},
#      u'external_urls': {u'spotify': u'https://open.spotify.com/track/3SNlNjtrf55udu1V3CCm1B'},
#      u'href': u'https://api.spotify.com/v1/tracks/3SNlNjtrf55udu1V3CCm1B',
#      u'id': u'3SNlNjtrf55udu1V3CCm1B',
#      u'name': u'Ghost (Bj\xf6rn Remix)',
#      u'popularity': 34,
#      u'preview_url': u'https://p.scdn.co/mp3-preview/46e9d33d9653f93b8e984405d7b019bf068565b6?cid=af834c73413b4e3abe51409e54a12b56',
#      u'track_number': 1,
#      u'type': u'track',
#      u'uri': u'spotify:track:3SNlNjtrf55udu1V3CCm1B'}}],
#   u'limit': 100,
#   u'next': u'https://api.spotify.com/v1/users/gravsibs/playlists/7zhfzvSSo9Q0JWzkbw2w5j/tracks?offset=100&limit=100',
#   u'offset': 0,
#   u'previous': None,
#   u'total': 354},
#  u'type': u'playlist',
#  u'uri': u'spotify:user:gravsibs:playlist:7zhfzvSSo9Q0JWzkbw2w5j'}

# %%
df.head(10)
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.1090         0.652       239098   0.549          0.000008    6
# 1        0.2010         0.621       262922   0.758          0.215000    8
# 2        0.1650         0.758       196311   0.510          0.075500    1
# 3        0.2360         0.746       299440   0.809          0.000026    2
# 4        0.1730         0.832       201939   0.876          0.737000    6
# 5        0.2990         0.743       198000   0.564          0.000693    5
# 6        0.0189         0.680       232490   0.450          0.010900    8
# 7        0.2970         0.652       339357   0.702          0.107000   11
# 8        0.0453         0.603       268303   0.827          0.619000    6
# 9        0.1450         0.646       173214   0.657          0.000057    0
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.0834    -9.604     0       0.0774  106.453               4    0.427
# 1    0.1230    -5.859     0       0.0321  105.056               4    0.117
# 2    0.2720   -10.645     1       0.0393  102.992               4    0.286
# 3    0.2350    -6.429     1       0.0329  104.989               4    0.520
# 4    0.1620    -5.124     0       0.2050  120.057               4    0.635
# 5    0.1090    -8.761     1       0.0450  120.012               4    0.512
# 6    0.0984   -10.638     1       0.0689   96.235               4    0.437
# 7    0.0982   -10.983     0       0.0377  115.993               4    0.345
# 8    0.0833    -7.372     1       0.0714  144.992               4    0.333
# 9    0.4590    -5.300     1       0.0628  139.990               4    0.420
#
#          artist                         song_title  target
# 0   Tove Styrke                Ego (Bearson Remix)     1.0
# 1         Janji                Aurora (feat. T.R.)     1.0
# 2  Gabriel Rios      Gold (Thomas Jack Radio Edit)     1.0
# 3      Diviners                        Tropic Love     1.0
# 4         Feder  Goodbye (feat. Lyse) [Radio Edit]     1.0
# 5        filous                     How Hard I Try     1.0
# 6    Noonie Bao      I'm In Love (Coucheron Remix)     1.0
# 7    Jerry Folk                  Next Wave Records     1.0
# 8     Hermitude                  Parallel Paradise     1.0
# 9   Purity Ring                   another eternity     1.0

# %%
k_df = pd.read_csv("data.csv")
k_df = k_df.drop(['Unnamed: 0'], axis=1)

# %%
k_df.columns
# Out:
# Index([u'acousticness', u'danceability', u'duration_ms', u'energy',
#        u'instrumentalness', u'key', u'liveness', u'loudness', u'mode',
#        u'speechiness', u'tempo', u'time_signature', u'valence', u'target',
#        u'song_title', u'artist'],
#       dtype='object')

# %%
k_df[k_df['target']==1].shape
# Out:
# (1020, 16)

# %% [markdown]
# # Example of spotify public playlist import

# %%
user_ID = "spotify"
playlist_URI = "37i9dQZF1DXa9xHlDa5fc6"
df, df['artist'], df['song_title'] = get_playlist(user_ID, playlist_URI, cid, secret)
df = df.drop(['analysis_url','id','type','track_href','uri'], axis=1)
df['target'] = np.ones(len(df))

# %%
df.head(10)
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0      0.000127         0.288       203520   0.786          0.000122   11
# 1      0.021100         0.574       231593   0.746          0.000136    4
# 2      0.085600         0.579       180400   0.584          0.000000    5
# 3      0.078800         0.500       241093   0.654          0.002380    6
# 4      0.227000         0.537       189651   0.713          0.650000    7
# 5      0.013200         0.640       216320   0.741          0.011200    1
# 6      0.198000         0.449       272600   0.511          0.009460    1
# 7      0.008410         0.527       224918   0.881          0.001320    0
# 8      0.178000         0.541       237568   0.718          0.000000    1
# 9      0.040100         0.633       354360   0.831          0.693000    4
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1920    -4.792     0       0.0379  167.916               4    0.357
# 1    0.1080    -4.782     1       0.0302  133.032               4    0.250
# 2    0.0958    -7.151     0       0.0438   80.001               4    0.421
# 3    0.1250    -5.886     0       0.0316  137.005               4    0.314
# 4    0.1000    -6.250     1       0.0272   93.198               4    0.352
# 5    0.1280    -4.077     0       0.0285  116.887               4    0.760
# 6    0.0759    -5.995     1       0.0419  116.286               4    0.209
# 7    0.3000    -6.227     1       0.0459  135.055               4    0.420
# 8    0.0956    -5.544     0       0.0295  146.037               4    0.539
# 9    0.1170    -5.053     1       0.0461  127.397               4    0.252
#
#               artist                   song_title  target
# 0           Wildlife                 Dead Century     1.0
# 1             MISSIO  Bottom Of The Deep Blue Sea     1.0
# 2        Foreign Air                  Free Animal     1.0
# 3       Andrew Belle                   Black Bear     1.0
# 4           Day Wave                         Drag     1.0
# 5        Tame Impala                     Currents     1.0
# 6         Mansionair                       Easier     1.0
# 7           Cape Cub                   All I Need     1.0
# 8       Tash Sultana          Jungle (Radio Edit)     1.0
# 9  Silversun Pickups       The Singles Collection     1.0

# %%
### Kygo Midnight Remix #####
user_ID = "giulia.celentano"
playlist_URI = "6HNpVQsvrWaU4uyGxmYFIO"
test_df, test_df['artist'], test_df['song_title'] = get_playlist(user_ID, playlist_URI, cid, secret)
test_df = test_df.drop(['analysis_url','id','type','track_href','uri'], axis=1)
test_df['target'] = np.ones(len(test_df))

# %% [markdown]
# ## Using a small subset of random songs and personal songs to train NN

# %%
rand = k_df[k_df['target']==0]

# %%
train = df.append(rand.head(100))

# %%
train.shape
# Out:
# (200, 16)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
#Source https://github.com/fchollet/keras/issues/5400
def precision(y_true, y_pred):
    """Precision metric.
    Only computes a batch-wise average of precision.
    Computes the precision, a metric for multi-label classification of
    how many selected items are relevant.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision


def recall(y_true, y_pred):
    """Recall metric.
    Only computes a batch-wise average of recall.
    Computes the recall, a metric for multi-label classification of
    how many relevant items are selected.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %%
def define_model(nb_feat,layers,nb_class):
    model = Sequential()                             # Sequential network model description
    model.add(Dense(layers[0],input_shape=(nb_feat,),\
                name='L1',\
                activation='sigmoid'))                       # Add 1st Dense Layer
    for i in range(1,len(layers)):
        model.add(Dense(layers[i],\
                name='L%i'%(i+1),\
                activation='sigmoid'))                       # Add ith Dense Layer

    model.add(Dense(units=nb_class,\
                    name='Classifier',\
                    activation='sigmoid'))                   # Add 4th Dense Layer, also the classification layer

    return model.compile(loss='binary_crossentropy',optimizer='sgd', metrics=['accuracy', recall, precision])

# %%
# Define Model Parameters
nb_feat   = 13             # no. of features/columns of input
layers    = [100,50,20]    # no. of nodes in layers
nb_class  = 1              # no. of output classes
model = Sequential()                             # Sequential network model description
model.add(Dense(layers[0],input_shape=(nb_feat,),\
            name='L1',\
            activation='sigmoid'))                       # Add 1st Dense Layer
for i in range(1,len(layers)):
    model.add(Dense(layers[i],\
            name='L%i'%(i+1),\
            activation='sigmoid'))                       # Add ith Dense Layer

model.add(Dense(units=nb_class,\
                name='Classifier',\
                activation='sigmoid'))                   # Add 4th Dense Layer, also the classification layer

model.compile(loss='binary_crossentropy',optimizer='sgd', metrics=['accuracy', recall, precision])        
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# L1 (Dense)                   (None, 100)               1400
# _________________________________________________________________
# L2 (Dense)                   (None, 50)                5050
# _________________________________________________________________
# L3 (Dense)                   (None, 20)                1020
# _________________________________________________________________
# Classifier (Dense)           (None, 1)                 21
# =================================================================
# Total params: 7,491
# Trainable params: 7,491
# Non-trainable params: 0
# _________________________________________________________________

# %%
scaler = StandardScaler()
print(scaler.fit(X))
X = train.drop(['target','artist','song_title'],axis=1).values
y = train['target'].values
X_normalized = scaler.transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.2)
print X.shape
X_normalized[0,:]
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)
# (200, 13)
# array([-0.72122026, -2.05244968, -0.52202806,  0.49672924, -0.48760978,
#         1.55110799,  0.007438  ,  0.60988451, -1.25669562, -0.60910644,
#         1.73592524,  0.12404825, -0.56574538])

# %%
pred = get_print_results(X_train, X_test, y_train, y_test, 20, 1)
pred
# Out:
# Epoch 1/20
# 160/160 [==============================] - 0s - loss: 0.7551 - acc: 0.4313 - recall: 0.4125 - precision: 0.4125
# Epoch 2/20
# 160/160 [==============================] - 0s - loss: 0.7002 - acc: 0.4813 - recall: 0.0562 - precision: 0.0562
# Epoch 3/20
# 160/160 [==============================] - 0s - loss: 0.6988 - acc: 0.5187 - recall: 0.0875 - precision: 0.0875
# Epoch 4/20
# 160/160 [==============================] - 0s - loss: 0.6973 - acc: 0.5000 - recall: 0.2187 - precision: 0.2187
# Epoch 5/20
# 160/160 [==============================] - 0s - loss: 0.6953 - acc: 0.5250 - recall: 0.1250 - precision: 0.1250
# Epoch 6/20
# 160/160 [==============================] - 0s - loss: 0.6910 - acc: 0.5500 - recall: 0.2312 - precision: 0.2312
# Epoch 7/20
# 160/160 [==============================] - 0s - loss: 0.6974 - acc: 0.5062 - recall: 0.1062 - precision: 0.1062
# Epoch 8/20
# 160/160 [==============================] - 0s - loss: 0.6968 - acc: 0.5000 - recall: 0.0500 - precision: 0.0500
# Epoch 9/20
# 160/160 [==============================] - 0s - loss: 0.6974 - acc: 0.5187 - recall: 0.0562 - precision: 0.0562
# Epoch 10/20
# 160/160 [==============================] - 0s - loss: 0.6927 - acc: 0.5563 - recall: 0.1625 - precision: 0.1625
# Epoch 11/20
# 160/160 [==============================] - 0s - loss: 0.6958 - acc: 0.5000 - recall: 0.2000 - precision: 0.2000
# Epoch 12/20
# 160/160 [==============================] - 0s - loss: 0.6951 - acc: 0.4938 - recall: 0.1687 - precision: 0.1687
# Epoch 13/20
# 160/160 [==============================] - 0s - loss: 0.6957 - acc: 0.5125 - recall: 0.1125 - precision: 0.1125
# Epoch 14/20
# 160/160 [==============================] - 0s - loss: 0.6953 - acc: 0.4875 - recall: 0.0812 - precision: 0.0812
# Epoch 15/20
# 160/160 [==============================] - 0s - loss: 0.6947 - acc: 0.5187 - recall: 0.0937 - precision: 0.0937
# Epoch 16/20
# 160/160 [==============================] - 0s - loss: 0.6916 - acc: 0.5500 - recall: 0.0875 - precision: 0.0875
# Epoch 17/20
# 160/160 [==============================] - 0s - loss: 0.6943 - acc: 0.4938 - recall: 0.1937 - precision: 0.1937
# Epoch 18/20
# 160/160 [==============================] - 0s - loss: 0.6877 - acc: 0.5250 - recall: 0.1625 - precision: 0.1625
# Epoch 19/20
# 160/160 [==============================] - 0s - loss: 0.6936 - acc: 0.5062 - recall: 0.0437 - precision: 0.0437
# Epoch 20/20
# 160/160 [==============================] - 0s - loss: 0.6906 - acc: 0.5250 - recall: 0.1625 - precision: 0.1625
# 0.848958333333
# array([[ 0.43919897],
#        [ 0.44095054],
#        [ 0.44481304],
#        [ 0.43213692],
#        [ 0.43301642],
#        [ 0.44821182],
#        [ 0.43998358],
#        [ 0.43949294],
#        [ 0.44653338],
#        [ 0.4566215 ],
#        [ 0.42522499],
#        [ 0.43864506],
#        [ 0.41512999],
#        [ 0.42032909],
#        [ 0.43248567],
#        [ 0.43788612],
#        [ 0.43995345],
#        [ 0.44747868],
#        [ 0.43097633],
#        [ 0.43440694],
#        [ 0.4309313 ],
#        [ 0.43624404],
#        [ 0.44476974],
#        [ 0.43496889],
#        [ 0.44164598],
#        [ 0.43435538],
#        [ 0.44447699],
#        [ 0.43734565],
#        [ 0.43549195],
#        [ 0.42807758],
#        [ 0.43743017],
#        [ 0.42916796],
#        [ 0.43645808],
#        [ 0.42062423],
#        [ 0.43510213],
#        [ 0.43698186],
#        [ 0.42251498],
#        [ 0.43078122],
#        [ 0.4271144 ],
#        [ 0.42358133]], dtype=float32)

# %% [markdown]
# ## Using all of Kaggle data to train and test

# %%
X = k_df.drop(['target','artist','song_title'],axis=1).values
y = k_df['target'].values

print(scaler.fit(X))
X_normalized = scaler.transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_normalized, y, test_size=0.2)
print X.shape
X_normalized[0,:]
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)
# (2017, 13)
# array([-0.68246675,  1.33287384, -0.50885114, -1.17770008, -0.40786448,
#        -0.91644642, -0.16629082, -0.45453036,  0.79573763,  3.76308393,
#         1.06670945,  0.12404825, -0.8530387 ])

# %%
def get_print_results(X_train, X_test, y_train, y_test, ep, bs):
    model.fit(X_train, y_train,nb_epoch=ep, batch_size=bs)
    pred = model.predict(X_test)
    fpr, tpr, thresholds = metrics.roc_curve(y_test, pred, pos_label=1)
    auc = metrics.roc_auc_score(y_test, pred)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='fpr vs tpr')
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.show()
    print auc
    return pred

# %%
pred = get_print_results(X_train, X_test, y_train, y_test, 10, 5)
pred[:10]
# Out:
# Epoch 1/10
# 1613/1613 [==============================] - 0s - loss: 0.6961 - acc: 0.4842 - recall: 0.5554 - precision: 0.3421
# Epoch 2/10
# 1613/1613 [==============================] - 0s - loss: 0.6952 - acc: 0.4823 - recall: 0.6516 - precision: 0.4264
# Epoch 3/10
# 1613/1613 [==============================] - 0s - loss: 0.6932 - acc: 0.5208 - recall: 0.6982 - precision: 0.4201
# Epoch 4/10
# 1613/1613 [==============================] - 0s - loss: 0.6949 - acc: 0.4935 - recall: 0.5638 - precision: 0.3698
# Epoch 5/10
# 1613/1613 [==============================] - 0s - loss: 0.6946 - acc: 0.5028 - recall: 0.7737 - precision: 0.4780
# Epoch 6/10
# 1613/1613 [==============================] - 0s - loss: 0.6937 - acc: 0.4997 - recall: 0.5910 - precision: 0.4231
# Epoch 7/10
# 1613/1613 [==============================] - 0s - loss: 0.6932 - acc: 0.5034 - recall: 0.6622 - precision: 0.4172
# Epoch 8/10
# 1613/1613 [==============================] - 0s - loss: 0.6938 - acc: 0.4898 - recall: 0.7393 - precision: 0.4741
# Epoch 9/10
# 1613/1613 [==============================] - 0s - loss: 0.6935 - acc: 0.5015 - recall: 0.5721 - precision: 0.4136
# Epoch 10/10
# 1613/1613 [==============================] - 0s - loss: 0.6926 - acc: 0.5127 - recall: 0.7393 - precision: 0.4271
# 0.580249638294
# array([[ 0.51029271],
#        [ 0.49667475],
#        [ 0.49828878],
#        [ 0.50489217],
#        [ 0.49933052],
#        [ 0.49178836],
#        [ 0.50349146],
#        [ 0.50740409],
#        [ 0.49104464],
#        [ 0.50402981]], dtype=float32)
