# %% [markdown]
# # ENGS 108 Applied Machine Learning
# ## Final Project
#
# ### Predicting likelyhood of a song being successful

# %% [markdown]
# Idea from the Kaggle data set found here: https://www.kaggle.com/geomack/spotifyclassification

# %%
import pandas as pd 
import numpy as np
import spotipy 
sp = spotipy.Spotify() 
from spotipy.oauth2 import SpotifyClientCredentials
from sklearn.model_selection import train_test_split
from sklearn import metrics
#for scaling the data
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt

# %%
cid ="af834c73413b4e3abe51409e54a12b56" #CLIENT ID
secret = "c572f66c7257454ea5189dee36084cdd" # CLIENT SECRET

# %%
def get_playlist(user_ID, playlist_URI, cid, secret):
    client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret) 
    sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) 
    sp.trace=False 
    playlist = sp.user_playlist(user_ID, playlist_URI) 
    songs = playlist["tracks"]["items"] 
    ids = [] 
    titles = []
    artists = []
    for i in range(len(songs)): 
        ids.append(songs[i]["track"]["id"])
        artists.append(songs[i]['track']['artists'][0]['name'])
        titles.append(songs[i]['track']['name'])
    features = sp.audio_features(ids) 
    return pd.DataFrame(features), artists, titles

# %% [markdown]
# ## Importing public playlist from personal account

# %%
user_ID = "gravsibs"
playlist_URI = "7zhfzvSSo9Q0JWzkbw2w5j" 
df, df['artist'], df['song_title'] = get_playlist(user_ID, playlist_URI, cid, secret)
df = df.drop(['analysis_url','id','type','track_href','uri'], axis=1)
df['target'] = np.ones(len(df))

# %% [markdown]
# For each song we get a string of information that looks like this

# %%
df.head(10)
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.1090         0.652       239098   0.549          0.000008    6
# 1        0.2010         0.621       262922   0.758          0.215000    8
# 2        0.1650         0.758       196311   0.510          0.075500    1
# 3        0.2360         0.746       299440   0.809          0.000026    2
# 4        0.1730         0.832       201939   0.876          0.737000    6
# 5        0.2990         0.743       198000   0.564          0.000693    5
# 6        0.0189         0.680       232490   0.450          0.010900    8
# 7        0.2970         0.652       339357   0.702          0.107000   11
# 8        0.0453         0.603       268303   0.827          0.619000    6
# 9        0.1450         0.646       173214   0.657          0.000057    0
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.0834    -9.604     0       0.0774  106.453               4    0.427
# 1    0.1230    -5.859     0       0.0321  105.056               4    0.117
# 2    0.2720   -10.645     1       0.0393  102.992               4    0.270
# 3    0.2350    -6.429     1       0.0329  104.989               4    0.493
# 4    0.1620    -5.124     0       0.2050  120.057               4    0.635
# 5    0.1090    -8.761     1       0.0450  120.012               4    0.512
# 6    0.0984   -10.638     1       0.0689   96.235               4    0.433
# 7    0.0982   -10.983     0       0.0377  115.993               4    0.343
# 8    0.0833    -7.372     1       0.0714  144.992               4    0.333
# 9    0.4590    -5.300     1       0.0628  139.990               4    0.413
#
#          artist                            song_title  target
# 0   Tove Styrke                   Ego - Bearson Remix     1.0
# 1         Janji                   Aurora (feat. T.R.)     1.0
# 2  Gabriel Rios         Gold - Thomas Jack Radio Edit     1.0
# 3      Diviners                           Tropic Love     1.0
# 4         Feder     Goodbye (feat. Lyse) - Radio Edit     1.0
# 5        filous                        How Hard I Try     1.0
# 6    Noonie Bao         I’m In Love - Coucheron Remix     1.0
# 7    Jerry Folk  Talk- Atlas Bound (Jerry Folk Remix)     1.0
# 8     Hermitude           HyperParadise - Flume Remix     1.0
# 9   Purity Ring                              bodyache     1.0

# %% [markdown]
# # Example of spotify public playlist import

# %%
user_ID = "spotify"
playlist_URI = "37i9dQZF1DXa9xHlDa5fc6"
df, df['artist'], df['song_title'] = get_playlist(user_ID, playlist_URI, cid, secret)
df = df.drop(['analysis_url','id','type','track_href','uri'], axis=1)
df['target'] = np.ones(len(df))

# %%
df.head(10)
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0      0.000127         0.288       203520   0.786          0.000122   11
# 1      0.021100         0.574       231593   0.746          0.000136    4
# 2      0.085600         0.579       180400   0.584          0.000000    5
# 3      0.078800         0.500       241093   0.654          0.002380    6
# 4      0.227000         0.537       189651   0.713          0.650000    7
# 5      0.013200         0.640       216320   0.741          0.011200    1
# 6      0.198000         0.449       272600   0.511          0.009460    1
# 7      0.008410         0.527       224918   0.881          0.001320    0
# 8      0.178000         0.541       237568   0.718          0.000000    1
# 9      0.040100         0.633       354360   0.831          0.693000    4
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1920    -4.792     0       0.0379  167.916               4    0.357
# 1    0.1080    -4.782     1       0.0302  133.032               4    0.261
# 2    0.0958    -7.151     0       0.0438   80.001               4    0.421
# 3    0.1250    -5.886     0       0.0316  137.005               4    0.314
# 4    0.1000    -6.250     1       0.0272   93.198               4    0.367
# 5    0.1280    -4.077     0       0.0285  116.887               4    0.760
# 6    0.0759    -5.995     1       0.0419  116.286               4    0.209
# 7    0.3000    -6.227     1       0.0459  135.055               4    0.420
# 8    0.0956    -5.544     0       0.0295  146.037               4    0.539
# 9    0.1170    -5.053     1       0.0461  127.397               4    0.252
#
#               artist                   song_title  target
# 0           Wildlife                 Dead Century     1.0
# 1             MISSIO  Bottom Of The Deep Blue Sea     1.0
# 2        Foreign Air                  Free Animal     1.0
# 3       Andrew Belle                       Pieces     1.0
# 4           Day Wave                         Drag     1.0
# 5        Tame Impala   The Less I Know The Better     1.0
# 6         Mansionair                       Easier     1.0
# 7           Cape Cub                   All I Need     1.0
# 8       Tash Sultana          Jungle (Radio Edit)     1.0
# 9  Silversun Pickups                     Lazy Eye     1.0

# %% [markdown]
# ## Importing Kaggle dataset of 2000 labeled songs
# This dataset is labeled subjectively by the maker of the dataset on Kaggle.
# It will be used as a representative of the pool of songs on all of spotify to create our version of Discover weekly.

# %%
k_df = pd.read_csv("data.csv")
k_df = k_df.drop(['Unnamed: 0'], axis=1)
k_df[k_df['target']==1].shape
# Out:
# (1020, 16)

# %% [markdown]
# ## Picking playlist from user as demo

# %%
### Kygo Midnight Remix #####
#user_ID = "giulia.celentano"
#playlist_URI = "6HNpVQsvrWaU4uyGxmYFIO"
user_ID = "gravsibs"
playlist_URI = "7zhfzvSSo9Q0JWzkbw2w5j" 

test_df, test_df['artist'], test_df['song_title'] = get_playlist(user_ID, playlist_URI, cid, secret)
test_df = test_df.drop(['analysis_url','id','type','track_href','uri'], axis=1)
test_df['target'] = np.ones(len(test_df))

# %% [markdown]
# ## Using a small subset of random songs and personal songs to train NN

# %%
rand = k_df[k_df['target']==0]

# %%
train = test_df.append(rand.tail(100))

# %%
train.shape
# Out:
# (200, 16)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
#Source https://github.com/fchollet/keras/issues/5400
def precision(y_true, y_pred):
    """Precision metric.
    Only computes a batch-wise average of precision.
    Computes the precision, a metric for multi-label classification of
    how many selected items are relevant.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision


def recall(y_true, y_pred):
    """Recall metric.
    Only computes a batch-wise average of recall.
    Computes the recall, a metric for multi-label classification of
    how many relevant items are selected.
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %%
def define_model(nb_feat,layers,nb_class):
    model = Sequential()                             # Sequential network model description
    model.add(Dense(layers[0],input_shape=(nb_feat,),\
                name='L1',\
                activation='sigmoid'))                       # Add 1st Dense Layer
    for i in range(1,len(layers)):
        model.add(Dense(layers[i],\
                name='L%i'%(i+1),\
                activation='sigmoid'))                       # Add ith Dense Layer

    model.add(Dense(units=nb_class,\
                    name='Classifier',\
                    activation='sigmoid'))                   # Add 4th Dense Layer, also the classification layer

    return model.compile(loss='binary_crossentropy',optimizer='sgd', metrics=['accuracy', recall, precision])

# %%
# Define Model Parameters
nb_feat   = 13             # no. of features/columns of input
layers    = [80,50,20]    # no. of nodes in layers
nb_class  = 1              # no. of output classes
model = Sequential()                             # Sequential network model description
model.add(Dense(layers[0],input_shape=(nb_feat,),\
            name='L1',\
            activation='sigmoid'))                       # Add 1st Dense Layer
for i in range(1,len(layers)):
    model.add(Dense(layers[i],\
            name='L%i'%(i+1),\
            activation='sigmoid'))                       # Add ith Dense Layer

model.add(Dense(units=nb_class,\
                name='Classifier',\
                activation='sigmoid'))                   # Add 4th Dense Layer, also the classification layer

model.compile(loss='binary_crossentropy',optimizer='sgd', metrics=['accuracy', recall, precision])        
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# L1 (Dense)                   (None, 80)                1120
# _________________________________________________________________
# L2 (Dense)                   (None, 50)                4050
# _________________________________________________________________
# L3 (Dense)                   (None, 20)                1020
# _________________________________________________________________
# Classifier (Dense)           (None, 1)                 21
# =================================================================
# Total params: 6,211
# Trainable params: 6,211
# Non-trainable params: 0
# _________________________________________________________________

# %%
def get_print_results(X_train, X_test, y_train, y_test, ep, bs):
    model.fit(X_train, y_train,nb_epoch=ep, batch_size=bs)
    pred = model.predict(X_test)
    fpr, tpr, thresholds = metrics.roc_curve(y_test, pred, pos_label=1)
    auc = metrics.roc_auc_score(y_test, pred)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label='fpr vs tpr')
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc='best')
    plt.show()
    print auc
    return pred, auc

# %%
scaler = StandardScaler()
X = train.drop(['target'],axis=1).values
y = train['target'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

test_song = X_test[:,10]
test_art = X_test[:,1]

X_test = np.delete(X_test,[1,10],1)
X_train = np.delete(X_train,[1,10],1)

print(scaler.fit(X_train))
X_train = scaler.transform(X_train)

print(scaler.fit(X_test))
X_test = scaler.transform(X_test)


print X_train.shape
X_train[15,:]
# Out:
# array([ 0.63836014, -0.21993993,  0.33377021, -1.83873223, -0.42506918,
#        -1.45358614, -0.44696531, -1.36168821, -1.14840785, -0.52073327,
#         1.51803286,  0.1382327 , -0.57343281])

# %%
pred = get_print_results(X_train, X_test, y_train, y_test, 20, 1)
pred[:10]
# Out:
# Epoch 1/20
# 160/160 [==============================] - 0s - loss: 0.6998 - acc: 0.4938 - recall: 0.1687 - precision: 0.1687
# Epoch 2/20
# 160/160 [==============================] - 0s - loss: 0.6990 - acc: 0.4437 - recall: 0.3625 - precision: 0.3625
# Epoch 3/20
# 160/160 [==============================] - 0s - loss: 0.6960 - acc: 0.5438 - recall: 0.2250 - precision: 0.2250
# Epoch 4/20
# 160/160 [==============================] - 0s - loss: 0.6966 - acc: 0.5312 - recall: 0.3187 - precision: 0.3187
# Epoch 5/20
# 160/160 [==============================] - 0s - loss: 0.6999 - acc: 0.4813 - recall: 0.3750 - precision: 0.3750
# Epoch 6/20
# 160/160 [==============================] - 0s - loss: 0.6987 - acc: 0.4625 - recall: 0.3437 - precision: 0.3437
# Epoch 7/20
# 160/160 [==============================] - 0s - loss: 0.6975 - acc: 0.5000 - recall: 0.2812 - precision: 0.2812
# Epoch 8/20
# 160/160 [==============================] - 0s - loss: 0.6987 - acc: 0.4688 - recall: 0.3750 - precision: 0.3750
# Epoch 9/20
# 160/160 [==============================] - 0s - loss: 0.6972 - acc: 0.4938 - recall: 0.3125 - precision: 0.3125
# Epoch 10/20
# 160/160 [==============================] - 0s - loss: 0.6970 - acc: 0.5312 - recall: 0.3375 - precision: 0.3375
# Epoch 11/20
# 160/160 [==============================] - 0s - loss: 0.6959 - acc: 0.4938 - recall: 0.2875 - precision: 0.2875
# Epoch 12/20
# 160/160 [==============================] - 0s - loss: 0.6966 - acc: 0.4938 - recall: 0.3312 - precision: 0.3312
# Epoch 13/20
# 160/160 [==============================] - 0s - loss: 0.6956 - acc: 0.4750 - recall: 0.2687 - precision: 0.2687
# Epoch 14/20
# 160/160 [==============================] - 0s - loss: 0.6965 - acc: 0.5000 - recall: 0.3750 - precision: 0.3750
# Epoch 15/20
# 160/160 [==============================] - 0s - loss: 0.6962 - acc: 0.4875 - recall: 0.4250 - precision: 0.4250
# Epoch 16/20
# 160/160 [==============================] - 0s - loss: 0.6886 - acc: 0.5375 - recall: 0.2500 - precision: 0.2500
# Epoch 17/20
# 160/160 [==============================] - 0s - loss: 0.6957 - acc: 0.5250 - recall: 0.4125 - precision: 0.4125
# Epoch 18/20
# 160/160 [==============================] - 0s - loss: 0.6947 - acc: 0.5250 - recall: 0.4000 - precision: 0.4000
# Epoch 19/20
# 160/160 [==============================] - 0s - loss: 0.6935 - acc: 0.5438 - recall: 0.4500 - precision: 0.4500
# Epoch 20/20
# 160/160 [==============================] - 0s - loss: 0.6916 - acc: 0.5250 - recall: 0.1875 - precision: 0.1875
# 0.709595959596
# array([[ 0.53505892],
#        [ 0.52751958],
#        [ 0.53220332],
#        [ 0.55563599],
#        [ 0.56351376],
#        [ 0.52532768],
#        [ 0.53159666],
#        [ 0.55035043],
#        [ 0.53932101],
#        [ 0.5500133 ]], dtype=float32)

# %%
## Fix for wierd error
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xe8 in position 1: ordinal not in range(128).


import sys  
reload(sys)  
sys.setdefaultencoding('utf8')

# %% [markdown]
# ## Displaying the 5 highest predicted songs in the training dataset

# %%
X_test = np.append(X_test,pred, axis=1)
X_test = np.append(X_test,[[str(x)] for x in test_song], axis=1)
X_test = np.append(X_test,[[str(x)] for x in test_art], axis=1)
out = pd.DataFrame(X_test, columns = k_df.columns.values)
out.sort_values('target', ascending=False).head(5)
# Out:
#        acousticness      danceability      duration_ms           energy  \
# 16  -0.782062937861   -0.293461322889  -0.803578313088   0.544978066539
# 21   0.331332452337    0.567307774748   -1.04310211071  -0.514748681732
# 30  -0.686778904206   0.0493228310372  -0.534696376965    1.29901440665
# 29  -0.789988704575  -0.0877908305333  -0.187456121208   0.871047835237
# 4   -0.750709537184     1.82418300581  -0.835475647272   0.259667018927
#
#    instrumentalness             key         liveness          loudness  \
# 16  -0.409018115952  0.707558174007  -0.741487590325   -0.207490806879
# 21   -0.40931085551   1.21295686973   0.423519704321  -0.0471072959298
# 30  -0.410602947354  0.454858826147   -1.13269991643      1.3178678788
# 29   -0.41057155356  0.960257521867   -1.08523665628    0.691771820019
# 4   -0.410552071237  0.202159478288   -1.13341905673    0.216196115093
#
#              mode      speechiness             tempo  time_signature  \
# 16  0.53881590608   -0.43654873099     0.19108504413  0.160128153805
# 21  0.53881590608  -0.313785182897  -0.0941294271114  0.160128153805
# 30  0.53881590608   0.214564264596    0.640679948746  0.160128153805
# 29  0.53881590608  -0.501815427445     0.57771551374  0.160128153805
# 4   0.53881590608    1.81826023463   -0.640590228432  0.160128153805
#
#              valence          target  \
# 16  -0.0056487064665  0.576032221317
# 21   -0.719645203832  0.571500897408
# 30  -0.0689142188913  0.565973818302
# 29    0.803246059536  0.563892781734
# 4      2.19508733288  0.563513755798
#
#                                            song_title          artist
# 16                              Teach Me - Radio Edit        Bakermat
# 21  On Trees and Birds and Fire - Sam Feldt & Bloo...        I Am Oak
# 30                                        Ex's & Oh's       Elle King
# 29                                          Avalanche   WALK THE MOON
# 4          Jenny from the Block - Track Masters Remix  Jennifer Lopez

# %% [markdown]
# ## Predicting which songs in the large pool most likely to like

# %%
X = k_df.drop(['target'],axis=1).values
test_song = X[:,13]
test_art = X[:,14]
X_test = np.delete(X,[13,14],1)

print(scaler.fit(X_test))
X_test = scaler.transform(X_test)


print X_test.shape
X_test[15,:]
# Out:
# array([-0.6486108 ,  0.11539969, -0.7073224 ,  0.7155467 , -0.28190074,
#         0.18024443,  0.80530371,  0.1192911 ,  0.79573763,  0.78229782,
#        -0.81019834,  0.12404825, -0.72760077])

# %%
pred = model.predict(X_test)
X_test = np.append(X_test,pred, axis=1)
X_test = np.append(X_test,[[x] for x in test_art], axis=1)
X_test = np.append(X_test,[[x] for x in test_song], axis=1)
out = pd.DataFrame(X_test, columns = k_df.columns.values)
out.sort_values('target', ascending=False).head (5)
# Out:
#        acousticness     danceability     duration_ms          energy  \
# 1531  2.89472169996   -1.87231320371  -0.14559517488  -3.09853689473
# 1537  2.39457704717   -1.22630651238   1.11548489181  -3.16560920545
# 1569    2.736983771  -0.977842400329   2.81677170004  -3.05715185194
# 1549  3.01398696332   -1.04617003114  0.529355959884  -3.03431872489
# 1598  2.94473616524   -2.87238125472   2.58284476391  -3.13278658531
#
#      instrumentalness              key         liveness        loudness  \
# 1531   0.603141030065   -1.19061912909   -0.71836242014  -6.21189004006
# 1537  -0.480366868868  -0.916446417206  -0.598682563371  -4.85870310977
# 1569  -0.433130465028   -1.46479184097  -0.631498007969  -3.56215379318
# 1549    2.73427180796    1.27693527784  -0.617985766075  -5.94944250612
# 1598   0.749610499336    1.27693527784  -0.166290822785  -6.38073926402
#
#                 mode      speechiness            tempo  time_signature  \
# 1531  0.795737632996  -0.650259088503   -2.76413304785  0.124048247191
# 1537  -1.25669562244  -0.614667612576  -0.400212774013  0.124048247191
# 1569  0.795737632996  -0.586861772008  -0.458385895693  0.124048247191
# 1549  0.795737632996  -0.614667612576   -2.16144901209  0.124048247191
# 1598  0.795737632996  -0.535699025364   0.716358825035  0.124048247191
#
#              valence          target       song_title  \
# 1531   -1.3831151077  0.590809345245     Bill Charlap
# 1537   -1.3831151077   0.58974480629      Miles Davis
# 1569   -1.5206921906  0.587529599667   David Halliday
# 1549  -1.64370228825  0.586181759834       Hank Jones
# 1598  -1.77237732462  0.584764957428  Robert Schumann
#
#                                                  artist
# 1531          I Was So Young, and You Were So Beautiful
# 1537                                      Blue in Green
# 1569                                        Dreamsville
# 1549                                            Eleanor
# 1598  Piano Quartet in E flat, Op.47: 3. Andante can...

# %% [markdown]
# The songs with the highest target are all coffee table jazz which is somewhat similar to Kygo Midnight Remixes in terms of feature values.

# %% [markdown]
# ## Varying layers to find the best AUC

# %%
scaler = StandardScaler()
X = train.drop(['target'],axis=1).values
y = train['target'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

test_song = X_test[:,10]
test_art = X_test[:,1]

X_test = np.delete(X_test,[1,10],1)
X_train = np.delete(X_train,[1,10],1)

print(scaler.fit(X_train))
X_train = scaler.transform(X_train)

print(scaler.fit(X_test))
X_test = scaler.transform(X_test)


print X_train.shape
X_train[15,:]
# Out:
# array([-0.33808779,  0.26398692,  0.14383941, -0.97020488, -0.38293526,
#         0.47060817, -0.48153076, -0.37360949,  0.76430257, -0.42904452,
#        -1.3406361 ,  0.15532561,  0.2991309 ])

# %%
aucs = []
nn = []
for layer in range(2,5):
    for node in range(10,200,10):
        # Define Model Parameters
        nb_feat   = 13             # no. of features/columns of input
        layers = []
        for scale in range(layer):
            layers.append(node/(scale+1))
        nb_class  = 1              # no. of output classes
        model = Sequential()                             # Sequential network model description
        model.add(Dense(layers[0],input_shape=(nb_feat,),\
                    name='L1',\
                    activation='sigmoid'))                       # Add 1st Dense Layer
        for i in range(1,len(layers)):
            model.add(Dense(layers[i],\
                    name='L%i'%(i+1),\
                    activation='sigmoid'))                       # Add ith Dense Layer

        model.add(Dense(units=nb_class,\
                        name='Classifier',\
                        activation='sigmoid'))                   # Add 4th Dense Layer, also the classification layer

        model.compile(loss='binary_crossentropy',optimizer='sgd', metrics=['accuracy', recall, precision])        
        model.summary()
        pred , auc = get_print_results(X_train, X_test, y_train, y_test, 10, 1)
        aucs.append(auc)
        nn.append(layers)

# %%
plt.plot(aucs)
plt.show()

# %% [markdown]
# ## Using all of Kaggle data to train and test

# %%
# Define Model Parameters
nb_feat   = 13             # no. of features/columns of input
layers    = [100,80,50]    # no. of nodes in layers
nb_class  = 1              # no. of output classes
model = Sequential()                             # Sequential network model description
model.add(Dense(layers[0],input_shape=(nb_feat,),\
            name='L1',\
            activation='sigmoid'))                       # Add 1st Dense Layer
for i in range(1,len(layers)):
    model.add(Dense(layers[i],\
            name='L%i'%(i+1),\
            activation='sigmoid'))                       # Add ith Dense Layer

model.add(Dense(units=nb_class,\
                name='Classifier',\
                activation='sigmoid'))                   # Add 4th Dense Layer, also the classification layer

model.compile(loss='binary_crossentropy',optimizer='sgd', metrics=['accuracy', recall, precision])        
model.summary()

# %%
X = k_df.drop(['target'],axis=1).values
y = k_df['target'].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

test_song = X_test[:,13]
test_art = X_test[:,14]

X_test = np.delete(X_test,[13,14],1)
X_train = np.delete(X_train,[13,14],1)

print(scaler.fit(X_train))
X_train = scaler.transform(X_train)

print(scaler.fit(X_test))
X_test = scaler.transform(X_test)


print X_train.shape
X_train[15,:]

# %%
pred = get_print_results(X_train, X_test, y_train, y_test, 10, 5)
pred[:10]

# %%
#X_test[:,:-1] = test_art
X_test = np.append(X_test,pred, axis=1)
X_test = np.append(X_test,[[x] for x in test_art], axis=1)
X_test = np.append(X_test,[[x] for x in test_song], axis=1)
out = pd.DataFrame(X_test, columns = k_df.columns.values)
out.sort_values('target').head (5)

# %%
out.sort_values('target')
